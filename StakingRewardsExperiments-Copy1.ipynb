# %%
# Imports
import requests
import json

# %%
# Billing Status
from Helper import StakingRewardsAPIClient

client = StakingRewardsAPIClient()
status = client.get_billing_status()
print(status)
# Out:
# {'plan_name': 'startup yearly v0', 'available_credits': 1496966, 'monthly_quota': 1500000, 'subscribed_at': '2025-11-24T07:32:41Z', 'requests_allowed': True, 'billing_date': '2026-02-18T13:27:47.137364Z'}

# %%
# Asset Queries
eth = client.get_assets(symbols=["ETH"], limit=1)
print(eth)
# Out:
# {'data': {'assets': [{'id': '5d27aa0de03dd80007d1eb49', 'name': 'Ethereum', 'slug': 'ethereum-2-0', 'description': "the world's largest and most decentralized Layer1 blockchain. The network is used for building dApps, holding assets, transacting and communicating without being controlled by a central authority. The Ethereum vision is to build a digital future on a global scale, that is powerful enough to help all of humanity", 'symbol': 'ETH'}]}}

# %%
result = client.get_asset_metrics(
      slug="polkadot",
      metric_keys=["reward_rate", "provider"],
      created_before="2023-06-28",
      metrics_limit=10
  )
print(result)
# Out:
# {'data': {'assets': [{'id': '5d27aa0ee03dd80007d1eb6d', 'slug': 'polkadot', 'logoUrl': 'https://coin-images.coingecko.com/coins/images/12171/large/polkadot.png?1696512008', 'metrics': [{'defaultValue': 14.835948403683611, 'createdAt': '2023-06-27T22:01:16.026146Z'}, {'defaultValue': 14.835916173737743, 'createdAt': '2023-06-27T20:01:07.394307Z'}, {'defaultValue': 14.835696505476331, 'createdAt': '2023-06-27T18:11:07.667837Z'}, {'defaultValue': 14.835516951370295, 'createdAt': '2023-06-27T16:01:13.578876Z'}, {'defaultValue': 14.852641094515928, 'createdAt': '2023-06-27T14:01:58.737205Z'}, {'defaultValue': 14.852593442400858, 'createdAt': '2023-06-27T12:10:17.547877Z'}, {'defaultValue': 14.852589686723764, 'createdAt': '2023-06-27T10:01:22.273959Z'}, {'defaultValue': 14.85250720223731, 'createdAt': '2023-06-27T08:01:23.624704Z'}, {'defaultValue': 14.8524890814507, 'createdAt': '2023-06-27T06:01:55.861665Z'}, {'defaultValue': 14.852486411180484, 'createdAt': '2023-06-27T04:01:27.988426Z'}]}]}}

# %%
providers = client.get_providers(asset_slug="cosmos")
print(providers)
# Out:
# {'data': {'providers': [{'slug': 'p2p-validator', 'rewardOptions': [{'metrics': [{'defaultValue': 19.06351149935919}]}]}, {'slug': 'figment-networks', 'rewardOptions': [{'metrics': [{'defaultValue': 18.818428911935055}]}]}, {'slug': 'kiln', 'rewardOptions': [{'metrics': [{'defaultValue': 19.01100151971126}]}]}, {'slug': 'allnodes', 'rewardOptions': [{'metrics': [{'defaultValue': 18.649477739423034}]}]}, {'slug': 'stake-fish', 'rewardOptions': [{'metrics': [{'defaultValue': 19.683184510055003}]}]}, {'slug': 'hashquark', 'rewardOptions': [{'metrics': [{'defaultValue': 19.65423787482338}]}]}, {'slug': 'chorus-one', 'rewardOptions': [{'metrics': [{'defaultValue': 19.151953968578734}]}]}, {'slug': 'nansen', 'rewardOptions': [{'metrics': [{'defaultValue': 19.65281496138043}]}]}, {'slug': 'stakin', 'rewardOptions': [{'metrics': [{'defaultValue': 19.67435992498762}]}]}, {'slug': 'stakely', 'rewardOptions': [{'metrics': [{'defaultValue': 19.683700132547347}]}]}]}}

# %%
# Total market cap
client.get_metrics(limit=1)
# Out:
# {'data': {'metrics': [{'defaultValue': 3183384258474.3066,
#     'changeAbsolutes': '{"1y": -124284384191.89453, "7d": 13913124235.17871, "24h": 99242363989.19092, "30d": -758711371721.6655, "90d": -791154185015.4048}',
#     'changePercentages': '{"1y": -3.7574617538385904, "7d": 0.43897305404924386, "24h": 3.217827434160872, "30d": -19.246396914119202, "90d": -19.90556126866289}',
#     'createdAt': '2025-11-26T22:03:08.928548Z'}]}}

# %%
# Find the top providers for a coin
validators = client.get_validators(symbol="ETH", limit=4)
print(validators)
# Out:
# {'data': {'assets': [{'id': '5d27aa0de03dd80007d1eb49', 'name': 'Ethereum', 'slug': 'ethereum-2-0', 'description': "the world's largest and most decentralized Layer1 blockchain. The network is used for building dApps, holding assets, transacting and communicating without being controlled by a central authority. The Ethereum vision is to build a digital future on a global scale, that is powerful enough to help all of humanity", 'symbol': 'ETH', 'metrics': [{'metricKey': 'active_validators', 'label': 'Active Validators', 'defaultValue': 923301}]}]}}

# %%
# Find the staked tokens for a asset slug
result = client.get_staked_tokens(asset_slug="cosmos", limit=10)
print(result)
# Out:
# {'data': {'rewardOptions': [{'providers': None, 'validators': [{'address': None, 'status': {'label': 'unknown'}, 'metrics': None}]}, {'providers': [{'slug': 'chorus-one'}], 'validators': [{'address': 'cosmosvaloper15urq2dtp9qce4fyc85m6upwm9xul3049e02707', 'status': {'label': 'active'}, 'metrics': [{'metricKey': 'staked_tokens', 'defaultValue': 5278968.642348851}]}]}, {'providers': [{'slug': 'nansen'}], 'validators': [{'address': 'cosmosvaloper1jlr62guqwrwkdt4m3y00zh2rrsamhjf9num5xr', 'status': {'label': 'active'}, 'metrics': [{'metricKey': 'staked_tokens', 'defaultValue': 4086149.456492351}]}]}, {'providers': [{'slug': 'p2p-validator'}], 'validators': [{'address': 'cosmosvaloper132juzk0gdmwuxvx4phug7m3ymyatxlh9734g4w', 'status': {'label': 'active'}, 'metrics': [{'metricKey': 'staked_tokens', 'defaultValue': 5342077.522632887}]}, {'address': 'wl_node_cosmos_p2p-validator_1', 'status': {'label': 'active'}, 'metrics': [{'metricKey': 'staked_tokens', 'defaultValue': 249258}]}]}, {'providers': [{'slug': 'dokia-capital'}], 'validators': [{'address': 'cosmosvaloper14lultfckehtszvzw4ehu0apvsr77afvyju5zzy', 'status': {'label': 'active'}, 'metrics': [{'metricKey': 'staked_tokens', 'defaultValue': 8633918.607275907}]}]}, {'providers': [{'slug': 'spark-pool'}], 'validators': [{'address': 'cosmosvaloper1rwh0cxa72d3yle3r4l8gd7vyphrmjy2kpe4x72', 'status': {'label': 'active'}, 'metrics': [{'metricKey': 'staked_tokens', 'defaultValue': 1345463.617575}]}]}, {'providers': [{'slug': 'iqlusion'}], 'validators': [{'address': 'cosmosvaloper1grgelyng2v6v3t8z87wu3sxgt9m5s03xfytvz7', 'status': {'label': 'active'}, 'metrics': [{'metricKey': 'staked_tokens', 'defaultValue': 1733485.1721550657}]}]}, {'providers': [{'slug': '01node'}], 'validators': [{'address': 'cosmosvaloper17mggn4znyeyg25wd7498qxl7r2jhgue8u4qjcq', 'status': {'label': 'active'}, 'metrics': [{'metricKey': 'staked_tokens', 'defaultValue': 454406.9560790064}]}]}, {'providers': [{'slug': 'coinone-node'}], 'validators': [{'address': 'cosmosvaloper1te8nxpc2myjfrhaty0dnzdhs5ahdh5agzuym9v', 'status': {'label': 'active'}, 'metrics': [{'metricKey': 'staked_tokens', 'defaultValue': 1841244.8428939823}]}]}, {'providers': [{'slug': 'stake-fish'}], 'validators': [{'address': 'cosmosvaloper1sjllsnramtg3ewxqwwrwjxfgc4n4ef9u2lcnj0', 'status': {'label': 'active'}, 'metrics': [{'metricKey': 'staked_tokens', 'defaultValue': 4473564.753330963}]}]}]}}

# %%
### Query 1, get all assets

query = """
{
  assets(limit: 500) {
    slug
    id
  }
}
"""

result = client.execute_raw_query(query)
assets = result['data']['assets']

print(f'Number of assets: {len(assets)}')
print('\n'.join(item['slug'] for item in assets))
# Out:
# Number of assets: 500
# cardano
# waves
# stellar
# eos
# tron
# cosmos
# ethereum-2-0
# ontology
# algorand
# polkadot
# chainlink
# gnosis
# livepeer
# irisnet
# dai
# energi
# secret-network
# orbs
# terra
# tezos
# havven
# harmony
# solana
# near-protocol
# kava
# crypto-com-coin
# skale
# avalanche
# fantom
# elrond
# kusama
# coti
# makerdao
# telos
# chromia
# usd-coin
# bitcoin
# tether
# aave
# maker
# trueusd
# decentraland
# nusd
# kyber-network
# matic-network
# band-protocol
# e-money
# yearn-finance
# true-usd
# curve-dao-token
# paxos-standard
# litecoin
# ripple
# gemini-dollar
# persistence
# the-graph
# akash
# stafi-protocol
# mantra-dao
# pax-gold
# nimiq
# uniswap
# sushi
# pancakeswap
# binance-smart-chain
# flow
# injective-protocol
# certik
# fuse-network-token
# filecoin
# orchid-protocol
# balancer
# wrapped-bitcoin
# sentinel
# stasis-eurs
# regen
# mina
# hydra
# euro-coin
# dydx
# axie-infinity
# akropolis
# api3
# sifchain
# dogecoin
# rocket-pool
# paraswap
# presearch
# osmosis
# staked-near
# evmos
# radix
# comdex
# phala-network
# apecoin
# aavegotchi
# asset-mantle
# terra-luna-2
# frax
# ethereum-name-service
# cheqd
# cudos
# agoric
# axelar
# desmos
# juno
# stargaze
# umee
# moonriver
# chihuahua-token
# bitcanna
# bitsong
# ki
# medibloc
# nym
# omniflix-network
# fetch-ai
# lp-3pool-curve
# passage
# audius
# canto
# usdd
# moonbeam
# stride
# changex
# casper-network
# aleph-zero
# astar
# staked-ether
# liquity-usd
# gmx
# aptos
# covalent
# partisia-blockchain
# xpla
# the-sandbox
# celestia
# sui
# quicksilver
# archway
# hedera-hashgraph
# onomy-protocol
# bifrost-native-coin
# xxcoin
# aura-network
# kyve-network
# chain4energy
# coreum
# hedera-usdc
# klever
# rocket-pool-eth
# neutron-3
# origin-ether
# islamic-coin
# sei-network
# staked-aave
# staked-aave-balancer-pool-token
# wrapped-steth
# frax-ether
# staked-frax-ether
# ankreth
# coinbase-wrapped-staked-eth
# binance-eth
# wrapped-beacon-eth
# voucher-ethereum-2-0
# elastos
# reth
# humans-ai
# s-gmx
# arbitrum
# stader-ethx
# social-escrowed-psp
# social-escrowed-psp2
# stakewise-v3-oseth
# optimism
# the-open-network
# autonity
# ether-fi-staked-eth
# wrapped-eeth
# starknet
# ondo-finance
# swell-network
# voucher-movr
# stake-link-staked-link
# stride-staked-dydx
# dinero-apxeth
# dinero-staked-eth
# andromeda-2
# dymension
# restaked-swell-eth
# angle-usd
# altlayer
# wmatic
# wrapped-xdai
# lightning-bitcoin
# jarvis-synthetic-euro
# usd-mars
# lido-dao-wormhole
# monerium-eur-money
# lido-staked-matic
# aerovek-aviation
# weth
# blazestake-staked-sol
# stake-dao-crv
# jito-staked-sol
# acala-dollar-acala
# universal-eth
# voucher-ksm
# voucher-dot
# voucher-glmr
# matrixgpt
# hord-heth
# wrapped-oeth
# stride-staked-evmos
# degenstogether
# wrapped-ether-mantle-bridge
# wrapped-ether-linea
# zeebu
# bridged-usd-coin-base
# bridged-wrapped-ether-stargate
# sable-coin
# multi-ai
# vara-network
# mountain-protocol-usdm
# bridged-wrapped-ether-manta-pacific
# savings-dai
# bridged-wrapped-ether-scroll
# aftermath-staked-sui
# amnis-staked-aptos-coin
# bridged-wrapped-ether-fuse
# lava
# aave-v3-maticx
# coti-governance-token
# stride-staked-comdex
# stride-staked-sommelier
# stride-staked-umee
# m2-global-wealth-limited-mmx
# mantle-staked-ether
# bridged-wrapped-ether-voltage-finance
# gogopool-ggavax
# wrapped-usdm
# milkyway-staked-tia
# kelp-dao-restaked-eth
# stride-staked-luna
# stride-staked-injective
# stride-staked-stars
# stride-staked-juno
# fxn-token
# stake-link
# white-whale
# ageur
# mimatic
# socean-staked-sol
# meveth
# frax-price-index-share
# dola-usd
# gho
# stride-staked-osmo
# stride-staked-atom
# tbtc
# bilira
# picasso
# benqi
# eusd-new
# crvusd
# chainflip
# dora-factory-2
# ethena-usde
# prisma-mkusd
# radiant-capital
# maverick-protocol
# pendle
# benqi-liquid-staked-avax
# paypal-usd
# sweth
# metis-token
# msol
# frax-share
# iota
# chiliz
# bittensor
# shiba-inu
# bifrost-voucher-manta
# bifrost-voucher-astr
# renzo-restaked-eth
# tston
# stride-staked-tia
# inception-restaked-wbeth
# inception-restaked-sweth
# inceptionlrt-sfrxet
# inception-restaked-cbeth
# inception-restaked-lseth
# inception-restaked-ethx
# inception-restaked-ankreth
# inception-restaked-reth
# inception-restaked-steth
# inception-restaked-meth
# inception-restaked-oeth
# inception-restaked-oseth
# zetachain
# staked-lyx-token
# metapool-ethereum
# pufeth
# staked-frax
# staked-fil
# stacked-stx
# zora-bridged-weth-zora-network
# stacks
# stride-staked-dym
# stake-dao-cake
# stake-dao-yfi
# stake-dao-fxn
# stake-dao-mav
# stake-dao-pendle
# stake-dao-80-bal-20-weth
# stake-dao-fxs
# stake-dao-fpis
# stake-dao-angle
# stake-dao-apw
# stake-dao-bpt
# ether-fi
# solanahub-staked-sol
# fluence
# omni-network
# ethena
# staked-metis-token
# liquid-staked-eth
# saga-2
# eigenda
# stride-staked-saga
# solv-btc
# lagrange
# eoracle
# xterio-mach
# brevis
# witness
# angle-euro
# xdai
# frankencoin
# eigenpie-sweth
# automata-multi-prover-avs
# renzo
# avail
# eigenlayer
# wrapped-ether-massa
# helius-staked-sol
# jupiter-staked-sol
# dodochain-mach
# openlayer
# subsquid
# definitive-shares-benqi-btcb
# definitive-shares-benqi-usdt
# definitive-shares-benqi-wethe
# definitive-shares-benqi-daie
# definitive-shares-benqi-linke
# definitive-shares-synapse-stableswap
# definitive-shares-synapse-weth
# definitive-shares-stargate-eth
# definitive-shares-stargate-usdce
# definitive-shares-stargate-usdc
# definitive-shares-stargate-dai
# definitive-shares-stargate-usdt
# definitive-shares-moonwell-cbeth
# definitive-shares-moonwell-dai
# definitive-shares-moonwell-eth
# definitive-shares-moonwell-usdc
# definitive-shares-hop-usdc
# definitive-shares-hop-usdce
# definitive-shares-moonwell-wsteth
# definitive-shares-moonwell-reth
# definitive-shares-benqi-usdc
# definitive-shares-benqi-savax
# definitive-shares-benqi-avax
# definitive-shares-hyperstaking-reth-moonwell
# definitive-shares-hyperstaking-cbeth-moonwell
# definitive-shares-hyperstaking-wsteth-compoundv3
# definitive-shares-hyperstaking-wsteth-morpho
# definitive-shares-hyperstaking-cbeth-aavev3
# definitive-shares-hyperstaking-wsteth-aavev3
# definitive-shares-hyperstaking-stmatic-aavev3
# definitive-shares-hyperstaking-savax-aavev3
# definitive-shares-hyperstaking-savax-benqi
# ion-weeth-wsteth-token
# ion-rseth-wsteth-token
# ion-rsweth-wsteth-token
# yieldnest-restaked-eth
# voucher-bnc
# voucher-fil
# usual-usd
# treasury-coti
# lagrange-zk
# ion-ezeth-weth-token
# wrapped-eth-taiko
# bridged-wrapped-ether-x-layer
# sanko-bridged-weth-sanko
# cyber-mach
# definitive-shares-hyperstaking-cbeth-morpho
# hyperlane
# gm-network-mach
# sy-king-karak-lrt
# yt-weethk-26sep2024
# pt-weethk-26sep2024
# pendle-lpt
# sy-mellow-pzeth
# yt-pzeth-26sep2024
# pt-pzeth-26sep2024
# sy-mellow-susde
# yt-rsusde-26sep2024
# pt-rsusde-26sep2024
# sy-mellow-ena
# yt-rsena-26sep2024
# pt-rsena-26sep2024
# sy-super-symbiotic-lrt
# yt-weeths-29aug2024
# pt-weeths-29aug2024
# sy-zircuit-etherfi-weeth
# yt-zs-weeth-22aug2024
# pt-zs-weeth-22aug2024
# sy-zircuit-staking-ezeth
# yt-zs-ezeth-22aug2024
# pt-zs-ezeth-22aug2024
# sy-zircuit-staking-rseth
# yt-zs-rseth-22aug2024
# pt-zs-rseth-22aug2024
# sy-bedrock-unieth
# yt-unieth-26sep2024
# pt-unieth-26sep2024
# sy-rsweth
# yt-rsweth-26sep2024
# pt-rsweth-26sep2024
# sy-mellow-amphreth
# yt-amphreth-25jul2024
# pt-amphreth-25jul2024
# sy-mellow-re7lrt
# yt-re7lrt-25jul2024
# pt-re7lrt-25jul2024
# sy-mellow-steakhouse-steaklrt
# yt-steaklrt-25jul2024
# pt-steaklrt-25jul2024
# sy-mellow-rsteth
# yt-rsteth-25jul2024
# pt-rsteth-25jul2024
# sy-etherfi-weeth
# yt-weeth-26sep2024
# pt-weeth-26sep2024
# yt-weeth-26dec2024
# pt-weeth-26dec2024
# sy-zircuit-staking-usde
# yt-zs-usde-22aug2024
# pt-zs-usde-22aug2024
# sy-karak-weeth
# yt-karak-weeth-26sep2024
# pt-karak-weeth-26sep2024
# sy-karak-susde
# yt-karak-susde-26sep2024
# pt-karak-susde-26sep2024
# sy-karak-usde
# yt-karak-usde-26sep2024
# pt-karak-usde-26sep2024
# sy-swell-l2-deposit-rsweth
# yt-sw2rsweth-25jul2024
# pt-sw2rsweth-25jul2024
# yt-weeth-25jul2024
# pt-weeth-25jul2024
# sy-ethena-susde
# yt-susde-25jul2024
# pt-susde-25jul2024
# yt-susde-26sep2024
# pt-susde-26sep2024
# sy-kelp-rseth
# yt-rseth-26sep2024
# pt-rseth-26sep2024
# sy-renzo-ezeth
# yt-ezeth-26sep2024
# pt-ezeth-26sep2024
# yt-ezeth-26dec2024
# pt-ezeth-26dec2024
# sy-puffer-eth
# yt-pufeth-26sep2024
# pt-pufeth-26sep2024
# sy-ethena-usde
# yt-usde-25jul2024
# pt-usde-25jul2024
# sy-ena
# yt-ena-29aug2024
# pt-ena-29aug2024
# sy-renzo-rez-staking
# yt-reztake-26sep2024
# pt-reztake-26sep2024
# usd0-liquid-bond
# covalent-x-token
# renzo-restaked-lst
# weeths
# yt-susde-24oct2024
# pt-susde-24oct2024
# yt-usde-24oct2024
# pt-usde-24oct2024
# yt-susde-26dec2024
# pt-susde-26dec2024
# yt-usde-26dec2024

# %%
## Get market cap for an asset
query = """
{
   assets(where: {slugs: ["cardano"], isActive: Any}, limit: 1) {
        metrics(limit: 10) {
            metricKey
            defaultValue
        }
    }
}
"""
result = client.execute_raw_query(query)
print(json.dumps(result, indent=4))
# Out:
# {
#     "data": {
#         "assets": [
#             {
#                 "metrics": [
#                     {
#                         "metricKey": "net_staking_flow",
#                         "defaultValue": 0
#                     },
#                     {
#                         "metricKey": "benchmark_commission",
#                         "defaultValue": 27.20370481652398
#                     },
#                     {
#                         "metricKey": "annualized_rewards_usd",
#                         "defaultValue": 206332312.6834773
#                     },
#                     {
#                         "metricKey": "staking_roi_365d",
#                         "defaultValue": 2.60051560993422
#                     },
#                     {
#                         "metricKey": "block_time_target",
#                         "defaultValue": 20
#                     },
#                     {
#                         "metricKey": "staked_tokens_trend_24h",
#                         "defaultValue": -1
#                     },
#                     {
#                         "metricKey": "staked_tokens",
#                         "defaultValue": 21019816840.543385
#                     },
#                     {
#                         "metricKey": "total_validators",
#                         "defaultValue": 2919
#                     },
#                     {
#                         "metricKey": "waiting_stake",
#                         "defaultValue": 456316936.47266006
#                     },
#                     {
#                         "metricKey": "active_validators",
#                         "defaultValue": 1000
#                     }
#                 ]
#             }
#         ]
#     }
# }

# %%
query = """
{
  providers(limit: 10) {
    name
    logoUrl
    country
    rewardOptions(limit: 5) {
      id
      type {
        key
        label
      }
      metrics(limit: 10) {
        metricKey
        defaultValue
      }
    }
  }
}
"""
result = client.execute_raw_query(query)
print(result)
# Out:
# {'data': {'providers': [{'name': 'Staked', 'logoUrl': 'https://storage.googleapis.com/stakingrewards-static/images/providers/production/eigenlayer/0x6573629204b65faac121c1b556b91a694d0e23c8.png', 'country': 'us', 'rewardOptions': [{'id': '5d34930fe03dd8000780b7a3', 'type': {'key': 'pos', 'label': 'pos'}, 'metrics': [{'metricKey': '30d_apr', 'defaultValue': 0.08998984800567686}, {'metricKey': 'activation_time', 'defaultValue': 1532036007.0}, {'metricKey': 'assets_under_management', 'defaultValue': 20790326.193907466}, {'metricKey': 'available_capacity', 'defaultValue': 3661230.503659999}, {'metricKey': 'available_delegation_capacity', 'defaultValue': 25086187.982741}, {'metricKey': 'available_staking_capacity', 'defaultValue': 7797101.096441001}, {'metricKey': 'baking_power', 'defaultValue': 35489982413494.0}, {'metricKey': 'block_fees', 'defaultValue': 22715688.0}, {'metricKey': 'block_rewards', 'defaultValue': 4025555365.0}, {'metricKey': 'capacity', 'defaultValue': 13579097.84568}]}, {'id': '5ef361ad97cfa00007ba4596', 'type': {'key': 'pos', 'label': 'pos'}, 'metrics': [{'metricKey': 'assets_under_management', 'defaultValue': 2627048.2552264966}, {'metricKey': 'available_capacity', 'defaultValue': 0}, {'metricKey': 'capacity', 'defaultValue': 0}, {'metricKey': 'commission', 'defaultValue': 10}, {'metricKey': 'daily_validator_revenue', 'defaultValue': 551.5834701083671}, {'metricKey': 'delegated_tokens', 'defaultValue': 23516423.381546997}, {'metricKey': 'lockup_time', 'defaultValue': 1814400.0}, {'metricKey': 'minimum', 'defaultValue': 1e-05}, {'metricKey': 'net_staking_flow', 'defaultValue': 34.323356788398165}, {'metricKey': 'net_staking_flow_7d', 'defaultValue': -12210.423326042}]}, {'id': '5ef6218d41746e0008003c0f', 'type': {'key': 'pos', 'label': 'pos'}, 'metrics': [{'metricKey': 'lockup_time', 'defaultValue': 1239035.0}, {'metricKey': 'minimum', 'defaultValue': 0}, {'metricKey': 'reward_frequency', 'defaultValue': 86400}, {'metricKey': 'reward_rate', 'defaultValue': 11.793236982236134}]}, {'id': '5ef622268105cb0007142f17', 'type': {'key': 'pos', 'label': 'pos'}, 'metrics': [{'metricKey': 'assets_under_management', 'defaultValue': 326239715.758264}, {'metricKey': 'available_capacity', 'defaultValue': 0}, {'metricKey': 'candidate_reward', 'defaultValue': 35451876.679391496}, {'metricKey': 'capacity', 'defaultValue': 0}, {'metricKey': 'commission', 'defaultValue': 10}, {'metricKey': 'daily_validator_revenue', 'defaultValue': 1673.6422215426649}, {'metricKey': 'delegated_tokens', 'defaultValue': 0}, {'metricKey': 'lockup_time', 'defaultValue': 259200}, {'metricKey': 'minimum', 'defaultValue': 1}, {'metricKey': 'net_staking_flow', 'defaultValue': 29237.495812}]}, {'id': '5ef62302b3a6250007455b00', 'type': {'key': 'pos', 'label': 'pos'}, 'metrics': [{'metricKey': 'minimum', 'defaultValue': 0}, {'metricKey': 'reward_frequency', 'defaultValue': 604800}, {'metricKey': 'reward_rate', 'defaultValue': 42.27786171660726}]}]}, {'name': 'Figment', 'logoUrl': 'https://storage.googleapis.com/stakingrewards-static/images/providers/production/figment_logo.png?random=0.725224064232785', 'country': 'CA', 'rewardOptions': [{'id': '5f05c86c3ff67100084831e1', 'type': {'key': 'pos', 'label': 'pos'}, 'metrics': [{'metricKey': 'assets_under_management', 'defaultValue': 155716.23729761783}, {'metricKey': 'available_capacity', 'defaultValue': 0}, {'metricKey': 'capacity', 'defaultValue': 0}, {'metricKey': 'commission', 'defaultValue': 10}, {'metricKey': 'daily_validator_revenue', 'defaultValue': 0}, {'metricKey': 'delegated_tokens', 'defaultValue': 389708.5556700006}, {'metricKey': 'lockup_time', 'defaultValue': 1814400.0}, {'metricKey': 'net_staking_flow', 'defaultValue': 0.30309458203783135}, {'metricKey': 'net_staking_flow_7d', 'defaultValue': -105610.87474246}, {'metricKey': 'oracle_status', 'defaultValue': 0}]}, {'id': '5f884f4b79d36100077ec8f7', 'type': {'key': 'pos', 'label': 'pos'}, 'metrics': [{'metricKey': 'assets_under_management', 'defa ...

# %%
query = """
{
  metrics(
    where: {
      rewardOption: null
      validator: null
      metricKeys: ["marketcap"]
    }
    limit: 1
  ) {
    defaultValue
    changeAbsolutes
    changePercentages
    createdAt
    asset
    provider
  }
}
"""
result = client.execute_raw_query(query)
print(result)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[13], line 20
#       1 query = """
#       2 {
#       3   metrics(
#    (...)
#      18 }
#      19 """
# ---> 20 result = client.execute_raw_query(query)
#      21 print(result)
#
# File ~/work/Helper/stakingrewards_api.py:189, in StakingRewardsAPIClient.execute_raw_query(self, query, use_cache)
#     177 def execute_raw_query(self, query, use_cache=True):
#     178     """
#     179     Executes an raw query string 1:1
#     180
#    (...)
#     186         dict: The JSON response from the API
#     187     """
# --> 189     return self._execute_query(query, use_cache=use_cache)
#
# File ~/work/Helper/stakingrewards_api.py:96, in StakingRewardsAPIClient._execute_query(self, query, variables, use_cache)
#      89     payload["variables"] = variables
#      91 response = requests.post(
#      92     self.BASE_URL,
#      93     json=payload,
#      94     headers=self.headers
#      95 )
# ---> 96 response.raise_for_status()
#      97 result = response.json()
#      99 # Save to cache
#
# File /opt/conda/lib/python3.11/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.stakingrewards.com/public/query

# %%
## Get staked tokens marketcap

query = """
{
  assets(where: { slugs: ["cardano"] }, limit: 1) {
    slug
    id
    metrics(where: { metricKeys: ["staked_tokens"] }, limit: 1) {
      metricKey
      defaultValue
      changeAbsolutes
      changePercentages
    }
  }
}
"""
result = client.execute_raw_query(query)
print(result)
# Out:
# {'data': {'assets': [{'slug': 'cardano', 'id': '5d27aa08e03dd80007d1ea6e', 'metrics': [{'metricKey': 'staked_tokens', 'defaultValue': 21404584013.280006, 'changeAbsolutes': '{"1y": -508059700.4425316, "7d": -13162949.566673279, "24h": 72252725.34853745, "30d": -476870547.12327576, "90d": -481099996.4971657}', 'changePercentages': '{"1y": -2.318568708915598, "7d": -0.06145814305074675, "24h": 0.33870055913398284, "30d": -2.179336596691435, "90d": -2.1982406228758484}'}]}]}}

# %%
query = """
{
  rewardOptions(
    where: {
      inputAsset: { slugs: ["cardano"] }
      typeKeys: ["pos"]
    }
    limit: 10
    offset: 0
  ) {
    providers(limit: 2) {
      slug
    }
    validators(limit: 100) {
      address
      status {
        label
      }
      metrics(where: { metricKeys: ["staked_tokens"] }, limit: 1) {
        metricKey
        defaultValue
      }
    }
  }
}
"""
result = client.execute_raw_query(query)
rewardOptions = result['data']['rewardOptions']
sum = 0.0
for rewardOption in rewardOptions:
    providers = rewardOption['providers']
    for provider in providers:
        print(provider['slug'])
    validators = rewardOption['validators']
    for validator in validators:
        metrics = validator['metrics']
        for metric in metrics:
            if metric['metricKey'] == 'staked_tokens':
                print(metric['defaultValue'])
                sum += metric['defaultValue']

print(sum)
# Out:
# cardanoamsterdam
# 3810102.152475
# clrpool
# 4423103.941152
# 1-percent-pool-v2
# 917197.994816
# 10526694.43946
# 10092043.237211
# 8357436.039044
# 243405.922763
# 370298.756069
# 2532711.645362
# grow-team
# 13612206.585791
# stakenuts
# 5717669.946991
# zion-stake-pool
# 2229474.909243
# adafr
# 71338919.847084
# mango-farm
# 1366554.680694
# banderini
# 18943545.922984
# queen-ada
# 55370140.703104
# 209851506.724243

# %%
# More Asset Properties
query = """
{
  assets(where: { symbols: ["ETH"] }, limit: 1) {
    slug
    id
    logoUrl
    underlyingAssets
  }
}
"""

result = client.execute_raw_query(query)
print(result)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[16], line 13
#       1 # More Asset Properties
#       2 query = """
#       3 {
#       4   assets(where: { symbols: ["ETH"] }, limit: 1) {
#    (...)
#      10 }
#      11 """
# ---> 13 result = client.execute_raw_query(query)
#      14 print(result)
#
# File ~/work/Helper/stakingrewards_api.py:189, in StakingRewardsAPIClient.execute_raw_query(self, query, use_cache)
#     177 def execute_raw_query(self, query, use_cache=True):
#     178     """
#     179     Executes an raw query string 1:1
#     180
#    (...)
#     186         dict: The JSON response from the API
#     187     """
# --> 189     return self._execute_query(query, use_cache=use_cache)
#
# File ~/work/Helper/stakingrewards_api.py:96, in StakingRewardsAPIClient._execute_query(self, query, variables, use_cache)
#      89     payload["variables"] = variables
#      91 response = requests.post(
#      92     self.BASE_URL,
#      93     json=payload,
#      94     headers=self.headers
#      95 )
# ---> 96 response.raise_for_status()
#      97 result = response.json()
#      99 # Save to cache
#
# File /opt/conda/lib/python3.11/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.stakingrewards.com/public/query

# %%
## Reward Options
query = """
{
    rewardOptions(
        where: { providers: { slugs: ["allnodes"] } }
        limit: 10
        order: { metricKey_desc: "staked_tokens" }
      ) {
        inputAssets(limit: 1) {
          slug
        }
        metrics(where: { metricKeys: ["staked_tokens"] }, limit: 1) {
          defaultValue
        }
        validators(limit: 10) {
          address
          metrics(
            where: {
              metricKeys: [
                "commission"
                "staking_wallets"
                "self_staked_tokens"
                "staked_tokens"
                "reward_rate"
                "staking_share"
                "net_staking_flow_7d"
              ]
            }
            limit: 7
          ) {
            label
            metricKey
            defaultValue
          }
        }
    }
}

"""
result = client.execute_raw_query(query)
print(json.dumps(result, indent=4))
# Out:
# {
#     "data": {
#         "rewardOptions": [
#             {
#                 "inputAssets": [
#                     {
#                         "slug": "sifchain"
#                     }
#                 ],
#                 "metrics": [
#                     {
#                         "defaultValue": 1451724725.5518897
#                     }
#                 ],
#                 "validators": [
#                     {
#                         "address": "sifvaloper1ddlw0cz4v0grzek88z0vm34ktcfsac8du78yhg",
#                         "metrics": [
#                             {
#                                 "label": "Commission",
#                                 "metricKey": "commission",
#                                 "defaultValue": 10
#                             },
#                             {
#                                 "label": "Net Staking Flow 7d",
#                                 "metricKey": "net_staking_flow_7d",
#                                 "defaultValue": -3978.159562291
#                             },
#                             {
#                                 "label": "Reward Rate",
#                                 "metricKey": "reward_rate",
#                                 "defaultValue": 59.895238967468636
#                             },
#                             {
#                                 "label": "Self-Staked Tokens",
#                                 "metricKey": "self_staked_tokens",
#                                 "defaultValue": 2641716.0
#                             },
#                             {
#                                 "label": "Staked Tokens",
#                                 "metricKey": "staked_tokens",
#                                 "defaultValue": 1451724725.5518897
#                             },
#                             {
#                                 "label": "Staking Share",
#                                 "metricKey": "staking_share",
#                                 "defaultValue": 0.06419446066628884
#                             },
#                             {
#                                 "label": "Staking Wallets",
#                                 "metricKey": "staking_wallets",
#                                 "defaultValue": 983
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "inputAssets": [
#                     {
#                         "slug": "sentinel"
#                     }
#                 ],
#                 "metrics": [
#                     {
#                         "defaultValue": 1185586933.2986941
#                     }
#                 ],
#                 "validators": [
#                     {
#                         "address": "sentvaloper15pfdlwkue3xlpzzemxtq9aunynjzy9kewkvlz0",
#                         "metrics": [
#                             {
#                                 "label": "Commission",
#                                 "metricKey": "commission",
#                                 "defaultValue": 5
#                             },
#                             {
#                                 "label": "Net Staking Flow 7d",
#                                 "metricKey": "net_staking_flow_7d",
#                                 "defaultValue": 26667.763948944517
#                             },
#                             {
#                                 "label": "Reward Rate",
#                                 "metricKey": "reward_rate",
#                                 "defaultValue": 11.502319242649133
#                             },
#                             {
#                                 "label": "Self-Staked Tokens",
#                                 "metricKey": "self_staked_tokens",
#                                 "defaultValue": 437679
#                             },
#                             {
#                                 "label": "Staked Tokens",
#                                 "metricKey": "staked_tokens",
#                                 "defaultValue": 1185586933.2986941
#                             },
#                             {
#                                 "label": "Staking Share",
#                                 "metricKey": "staking_share",
#                                 "defaultValue": 0.05700024343239441
#                             },
#                             {
#                                 "label": "Staking Wallets",
#                                 "metricKey": "staking_wallets",
#                                 "defaultValue": 1297
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "inputAssets": [
#                     {
#                         "slug": "chihuahua-token"
#                     }
#                 ],
#                 "metrics": [
#                     {
#                         "defaultValue": 686020069.5756161
#                     }
#                 ],
#                 "validators": [
#                     {
#                         "address": "chihuahuavaloper125u84wy3897z5ducx0flmrjt59253vcqw40ttt",
#                         "metrics": [
#                             {
#                                 "label": null,
#                                 "metricKey": "commission",
#                                 "defaultValue": 5
#                             },
#                             {
#                                 "label": null,
#                                 "metricKey": "reward_rate",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "label": null,
#                                 "metricKey": "self_staked_tokens",
#                                 "defaultValue": 6099147.0
#                             },
#                             {
#                                 "label": null,
#                                 "metricKey": "staked_tokens",
#                                 "defaultValue": 686020069.5756161
#                             },
#                             {
#                                 "label": null,
#                                 "metricKey": "staking_share",
#                                 "defaultValue": 0.015936468164090955
#                             },
#                             {
#                                 "label": null,
#                                 "metricKey": "staking_wallets",
#                                 "defaultValue": 513
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "inputAssets": [
#                     {
#                         "slug": "monad"
#                     }
#                 ],
#                 "metrics": [
#                     {
#                         "defaultValue": 321579245.1678116
#                     }
#                 ],
#                 "validators": [
#                     {
#                         "address": "0x637b9590437055D0aab43a337475F42a5B900A85",
#                         "metrics": [
#                             {
#                                 "label": null,
#                                 "metricKey": "commission",
#                                 "defaultValue": 10
#                             },
#                             {
#                                 "label": null,
#                                 "metricKey": "reward_rate",
#                                 "defaultValue": 12.8086
#                             },
#                             {
#                                 "label": null,
#                                 "metricKey": "staked_tokens",
#                                 "defaultValue": 321579245.1678116
#                             },
#                             {
#                                 "label": null,
#                                 "metricKey": "staking_share",
#                                 "defaultValue": 0.007868560661774732
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "inputAssets": [
#                     {
#                         "slug": "islamic-coin"
#                     }
#                 ],
#                 "metrics": [
#                     {
#                         "defaultValue": 190607334.14821678
#                     }
#                 ],
#                 "validators": [
#                     {
#                         "address": "haqqvaloper15eafuvcrh3c07z4g3pqgq68n3lmsyu5jd9swsy",
#                         "metrics": [
#                             {
#                                 "label": "Commission",
#                                 "metricKey": "commission",
#                                 "defaultValue": 5
#                             },
#                             {
#                                 "label": null,
#                                 "metricKey": "reward_rate",
#                                 "defaultValue": 2.5646568367038878
#                             },
#                             {
#                                 "label": null,
#                                 "metricKey": "self_staked_tokens",
#                                 "defaultValue": 99774
#                             },
#                             {
#                                 "label": "Staked Tokens",
#                                 "metricKey": "staked_tokens",
#                                 "defaultValue": 190607334.14821678
#                             },
#                             {
#                                 "label": null,
#                                 "metricKey": "staking_share",
#                                 "defaultValue": 0.0794742590557498
#                             },
#                             {
#                                 "label": "Staking Wallets",
#                                 "metricKey": "staking_wallets",
#                                 "defaultValue": 16998
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "inputAssets": [
#                     {
#                         "slug": "asset-mantle"
#                     }
#                 ],
#                 "metrics": [
#                     {
#                         "defaultValue": 125071582.52413796
#                     }
#                 ],
#                 "validators": [
#                     {
#                         "address": "mantlevaloper16q7tsm4eadhw3sgqrlg2e32g6mfm8xzhjame6j",
#                         "metrics": [
#                             {
#                                 "label": "Commission",
#                                 "metricKey": "commission",
#                                 "defaultValue": 5
#                             },
#                             {
#                                 "label": "Net Staking Flow 7d",
#                                 "metricKey": "net_staking_flow_7d",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "label": "Reward Rate",
#                                 "metricKey": "reward_rate",
#                                 "defaultValue": 78.14855896825543
#                             },
#                             {
#                                 "label": "Self-Staked Tokens",
#                                 "metricKey": "self_staked_tokens",
#                                 "defaultValue": 855051.118506
#                             },
#                             {
#                                 "label": "Staked Tokens",
#                                 "metricKey": "staked_tokens",
#                                 "defaultValue": 125071582.52413796
#                             },
#                             {
#                                 "label": "Staking Share",
#                                 "metricKey": "staking_share",
#                                 "defaultValue": 0.0697691746601359
#                             },
#                             {
#                                 "label": "Staking Wallets",
#                                 "metricKey": "staking_wallets",
#                                 "defaultValue": 899
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "inputAssets": [
#                     {
#                         "slug": "crypto-com-coin"
#                     }
#                 ],
#                 "metrics": [
#                     {
#                         "defaultValue": 102013264.82883996
#                     }
#                 ],
#                 "validators": [
#                     {
#                         "address": "crocncl1u5ryf5jwc2jhd9xyvmasfqzacxp03v8dcj8xry",
#                         "metrics": [
#                             {
#                                 "label": "Commission",
#                                 "metricKey": "commission",
#                                 "defaultValue": 5
#                             },
#                             {
#                                 "label": "Net Staking Flow 7d",
#                                 "metricKey": "net_staking_flow_7d",
#                                 "defaultValue": 50175.71295345457
#                             },
#                             {
#                                 "label": "Reward Rate",
#                                 "metricKey": "reward_rate",
#                                 "defaultValue": 1.8596373602341028
#                             },
#                             {
#                                 "label": "Self-Staked Tokens",
#                                 "metricKey": "self_staked_tokens",
#                                 "defaultValue": 1
#                             },
#                             {
#                                 "label": "Staked Tokens",
#                                 "metricKey": "staked_tokens",
#                                 "defaultValue": 102013264.82883996
#                             },
#                             {
#                                 "label": "Staking Share",
#                                 "metricKey": "staking_share",
#                                 "defaultValue": 0.008420209994042855
#                             },
#                             {
#                                 "label": "Staking Wallets",
#                                 "metricKey": "staking_wallets",
#                                 "defaultValue": 9807
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "inputAssets": [
#                     {
#                         "slug": "irisnet"
#                     }
#                 ],
#                 "metrics": [
#                     {
#                         "defaultValue": 78406603.28629301
#                     }
#                 ],
#                 "validators": [
#                     {
#                         "address": "iva1muxh5wllk627klssx2w305lz8mdar5ne4ve9dc",
#                         "metrics": [
#                             {
#                                 "label": "Commission",
#                                 "metricKey": "commission",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "label": "Net Staking Flow 7d",
#                                 "metricKey": "net_staking_flow_7d",
#                                 "defaultValue": 1158.816596662215
#                             },
#                             {
#                                 "label": "Reward Rate",
#                                 "metricKey": "reward_rate",
#                                 "defaultValue": 10.503285258138218
#                             },
#                             {
#                                 "label": "Self-Staked Tokens",
#                                 "metricKey": "self_staked_tokens",
#                                 "defaultValue": 1
#                             },
#                             {
#                                 "label": "Staked Tokens",
#                                 "metricKey": "staked_tokens",
#                                 "defaultValue": 78406603.28629301
#                             },
#                             {
#                                 "label": "Staking Share",
#                                 "metricKey": "staking_share",
#                                 "defaultValue": 0.08103640890339428
#                             },
#                             {
#                                 "label": "Staking Wallets",
#                                 "metricKey": "staking_wallets",
#                                 "defaultValue": 1065
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "inputAssets": [
#                     {
#                         "slug": "matic-network"
#                     }
#                 ],
#                 "metrics": [
#                     {
#                         "defaultValue": 73024040.56322451
#                     }
#                 ],
#                 "validators": null
#             },
#             {
#                 "inputAssets": [
#                     {
#                         "slug": "islamic-coin"
#                     }
#                 ],
#                 "metrics": [
#                     {
#                         "defaultValue": 72735114.91301772
#                     }
#                 ],
#                 "validators": null
#             }
#         ]
#     }
# }

# %%
## Reward Options - for an asset get the providers
query = """
{
    rewardOptions(
        where: { inputAsset: { slugs: ["ethereum-2-0"] } }
        limit: 20
      ) {
        providers(where: { isActive: True } limit: 20) {
            id
            slug
            type {
               key
               label
            }
            name
            country
        }
    }
}
"""
result = client.execute_raw_query(query)
print(json.dumps(result, indent=4))
# Out:
# {
#     "data": {
#         "rewardOptions": [
#             {
#                 "providers": [
#                     {
#                         "id": "5eca1f4f159b3a0007b4a132",
#                         "slug": "blockdaemon",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "name": "Blockdaemon",
#                         "country": "US"
#                     }
#                 ]
#             },
#             {
#                 "providers": [
#                     {
#                         "id": "5d349314e03dd8000780b818",
#                         "slug": "infstones",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "name": "InfStones",
#                         "country": "US"
#                     }
#                 ]
#             },
#             {
#                 "providers": [
#                     {
#                         "id": "5d34930fe03dd8000780b7ba",
#                         "slug": "chorus-one",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "name": "Chorus One",
#                         "country": "CH"
#                     }
#                 ]
#             },
#             {
#                 "providers": [
#                     {
#                         "id": "5ee90c58ea998d000832c53c",
#                         "slug": "stakewise",
#                         "type": {
#                             "key": "liquid-staking",
#                             "label": "liquid-staking"
#                         },
#                         "name": "StakeWise",
#                         "country": "EE"
#                     }
#                 ]
#             },
#             {
#                 "providers": [
#                     {
#                         "id": "5d349313e03dd8000780b812",
#                         "slug": "stake-fish",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "name": "stakefish",
#                         "country": "VG"
#                     }
#                 ]
#             },
#             {
#                 "providers": null
#             },
#             {
#                 "providers": [
#                     {
#                         "id": "5d349310e03dd8000780b7cf",
#                         "slug": "p2p-validator",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "name": "P2P.org",
#                         "country": "KY"
#                     },
#                     {
#                         "id": "5fcce9256d61c4000724ac04",
#                         "slug": "lido-finance",
#                         "type": {
#                             "key": "liquid-staking",
#                             "label": "liquid-staking"
#                         },
#                         "name": "Lido Finance",
#                         "country": ""
#                     }
#                 ]
#             },
#             {
#                 "providers": null
#             },
#             {
#                 "providers": [
#                     {
#                         "id": "5fbe343bd25d730008fd48b6",
#                         "slug": "stakely",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "name": "Stakely",
#                         "country": "ES"
#                     },
#                     {
#                         "id": "5fcce9256d61c4000724ac04",
#                         "slug": "lido-finance",
#                         "type": {
#                             "key": "liquid-staking",
#                             "label": "liquid-staking"
#                         },
#                         "name": "Lido Finance",
#                         "country": ""
#                     }
#                 ]
#             },
#             {
#                 "providers": [
#                     {
#                         "id": "5ff6d5241acf780007736c19",
#                         "slug": "ankr",
#                         "type": {
#                             "key": "liquid-staking",
#                             "label": "liquid-staking"
#                         },
#                         "name": "ANKR",
#                         "country": "AE"
#                     }
#                 ]
#             },
#             {
#                 "providers": [
#                     {
#                         "id": "5f462a7ee1e4c20007980e84",
#                         "slug": "allnodes",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "name": "Allnodes",
#                         "country": "US"
#                     }
#                 ]
#             },
#             {
#                 "providers": [
#                     {
#                         "id": "5fcce9256d61c4000724ac04",
#                         "slug": "lido-finance",
#                         "type": {
#                             "key": "liquid-staking",
#                             "label": "liquid-staking"
#                         },
#                         "name": "Lido Finance",
#                         "country": ""
#                     },
#                     {
#                         "id": "624446e4b9f662000814c74b",
#                         "slug": "senseinode",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "name": "SenseiNode",
#                         "country": "VG"
#                     }
#                 ]
#             },
#             {
#                 "providers": [
#                     {
#                         "id": "5ee909cc5c39bc0009bd3bec",
#                         "slug": "rocket-pool",
#                         "type": {
#                             "key": "liquid-staking",
#                             "label": "liquid-staking"
#                         },
#                         "name": "Rocket Pool",
#                         "country": "AU"
#                     }
#                 ]
#             },
#             {
#                 "providers": [
#                     {
#                         "id": "5d34930fe03dd8000780b7ba",
#                         "slug": "chorus-one",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "name": "Chorus One",
#                         "country": "CH"
#                     },
#                     {
#                         "id": "5fcce9256d61c4000724ac04",
#                         "slug": "lido-finance",
#                         "type": {
#                             "key": "liquid-staking",
#                             "label": "liquid-staking"
#                         },
#                         "name": "Lido Finance",
#                         "country": ""
#                     }
#                 ]
#             },
#             {
#                 "providers": [
#                     {
#                         "id": "5d349314e03dd8000780b818",
#                         "slug": "infstones",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "name": "InfStones",
#                         "country": "US"
#                     },
#                     {
#                         "id": "5fcce9256d61c4000724ac04",
#                         "slug": "lido-finance",
#                         "type": {
#                             "key": "liquid-staking",
#                             "label": "liquid-staking"
#                         },
#                         "name": "Lido Finance",
#                         "country": ""
#                     }
#                 ]
#             },
#             {
#                 "providers": [
#                     {
#                         "id": "5d349314e03dd8000780b818",
#                         "slug": "infstones",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "name": "InfStones",
#                         "country": "US"
#                     },
#                     {
#                         "id": "6492a44419507600087c861e",
#                         "slug": "swell-network",
#                         "type": {
#                             "key": "liquid-staking",
#                             "label": "liquid-staking"
#                         },
#                         "name": "Swell Network",
#                         "country": "SG"
#                     }
#                 ]
#             },
#             {
#                 "providers": [
#                     {
#                         "id": "653f445586e42a0008838cc7",
#                         "slug": "stader-labs",
#                         "type": {
#                             "key": "liquid-staking",
#                             "label": "liquid-staking"
#                         },
#                         "name": "Staderlabs",
#                         "country": ""
#                     }
#                 ]
#             },
#             {
#                 "providers": [
#                     {
#                         "id": "5efc60135ef03f0007e0cfd0",
#                         "slug": "attestant",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "name": "Bitwise Onchain Solutions",
#                         "country": "GB"
#                     },
#                     {
#                         "id": "5fcce9256d61c4000724ac04",
#                         "slug": "lido-finance",
#                         "type": {
#                             "key": "liquid-staking",
#                             "label": "liquid-staking"
#                         },
#                         "name": "Lido Finance",
#                         "country": ""
#                     }
#                 ]
#             },
#             {
#                 "providers": [
#                     {
#                         "id": "5ea1cd6c94e5a30007166a73",
#                         "slug": "ledger-live",
#                         "type": {
#                             "key": "liquid-staking",
#                             "label": "liquid-staking"
#                         },
#                         "name": "Ledger Live",
#                         "country": "FR"
#                     },
#                     {
#                         "id": "628d1eacf2e72c0009bec517",
#                         "slug": "kiln",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "name": "Kiln",
#                         "country": "FR"
#                     }
#                 ]
#             },
#             {
#                 "providers": [
#                     {
#                         "id": "628d1eacf2e72c0009bec517",
#                         "slug": "kiln",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "name": "Kiln",
#                         "country": "FR"
#                     }
#                 ]
#             }
#         ]
#     }
# }

# %%
query = """
{
  rewardOptions(
    where: {
      providers: { slugs: ["kiln"] }
      inputAsset: { slugs: ["solana"] }
    }
    limit: 20
    order: { metricKey_desc: "staked_tokens" }
  ) {
    id
    inputAssets(limit: 1) { slug }
    metrics(where: { metricKeys: ["staked_tokens"] }, limit: 2) { defaultValue }
    validators(limit: 10) {
      id
      address
    }
  }
}

"""
result = client.execute_raw_query(query)
print(json.dumps(result, indent=4))
response = result
total_staked_tokens = sum(
    ro["metrics"][0]["defaultValue"]
    for ro in response.get("data", {}).get("rewardOptions", [])
    if ro.get("metrics") and ro["metrics"][0].get("defaultValue") is not None
)

print(f"Total staked tokens: {total_staked_tokens}")
# Out:
# {
#     "data": {
#         "rewardOptions": [
#             {
#                 "id": "2HvPGpm5slQCvekiT10J9Q==",
#                 "inputAssets": [
#                     {
#                         "slug": "solana"
#                     }
#                 ],
#                 "metrics": [
#                     {
#                         "defaultValue": 9938572.238318413
#                     }
#                 ],
#                 "validators": [
#                     {
#                         "id": "61671f01540b1d00076dd10d",
#                         "address": "DdCNGDpP7qMgoAy6paFzhhak2EeyCZcgjH7ak5u5v28m"
#                     },
#                     {
#                         "id": "668703ef0cac9717026caf27",
#                         "address": "HCvnhbT3Sn5RsueDisWzzn5FkW8tAqoQK1dr7cvAVzin"
#                     },
#                     {
#                         "id": "67c875373e68b89bfbdb76f5",
#                         "address": "wl_node_solana_Kiln-validator_1"
#                     },
#                     {
#                         "id": "67c875383e68b89bfbdb76fb",
#                         "address": "wl_node_solana_Kiln-validator_2"
#                     },
#                     {
#                         "id": "67c875393e68b89bfbdb7701",
#                         "address": "wl_node_solana_Kiln-validator_3"
#                     },
#                     {
#                         "id": "6826b61cfd65c3641574c2a5",
#                         "address": "7k6puiEcBsMABVJPqF8dRPc2LG5H4ewBR9aDhRChxfwb"
#                     }
#                 ]
#             }
#         ]
#     }
# }
# Total staked tokens: 9938572.238318413

# %%
## Global Market Cap
query = """
{
  assets(where: {symbols: ["ETH"]}, limit: 1) {
    id
    name
    slug
    symbol
    metrics(where: {metricKeys: ["price", "staking_marketcap"] }, limit: 10) {
      metricKey
      unit
      defaultValue
      changePercentages
    }
  }
}
"""
result = client.execute_raw_query(query)
print(json.dumps(result, indent=4))
# Out:
# {
#     "data": {
#         "assets": [
#             {
#                 "id": "5d27aa0de03dd80007d1eb49",
#                 "name": "Ethereum",
#                 "slug": "ethereum-2-0",
#                 "symbol": "ETH",
#                 "metrics": [
#                     {
#                         "metricKey": "price",
#                         "unit": "USD",
#                         "defaultValue": 3089.26,
#                         "changePercentages": "{\"1y\": -21.139840557105614, \"7d\": 1.7797604143329833, \"24h\": -5.025040658404832, \"30d\": -12.535355222663583, \"90d\": -33.87232803757122}"
#                     },
#                     {
#                         "metricKey": "staking_marketcap",
#                         "unit": "USD",
#                         "defaultValue": 110263359075.80104,
#                         "changePercentages": "{\"1y\": -16.636824825596698, \"7d\": 1.764214626514329, \"24h\": -5.025113547392528, \"30d\": -12.723263230582102, \"90d\": -34.02657060912577}"
#                     }
#                 ]
#             }
#         ]
#     }
# }

# %%
# Global Metrics
query = """
{
  metrics(
    where: {
      asset: null
      provider: null
      rewardOption: null
      validator: null
      metricKeys: ["staking_marketcap", "pos_assets_marketcap", "staking_wallets", "total_vsp_aum", "pow_assets_marketcap", "total_vsps"]
    }
    limit: 10
  ) {
    id
    defaultValue
    changeAbsolutes
    changePercentages
    createdAt
    metricKey
  }
}
"""
result = client.execute_raw_query(query)
print(json.dumps(result, indent=4))
# Out:
# {
#     "data": {
#         "metrics": [
#             {
#                 "id": "693d0f19d757e0be21cbe206",
#                 "defaultValue": 12075147.0,
#                 "changeAbsolutes": "{\"1y\": 644592, \"7d\": 195178, \"24h\": 181277, \"30d\": -125015, \"90d\": -206654}",
#                 "changePercentages": "{\"1y\": 5.639201246133718, \"7d\": 1.6429167449847724, \"24h\": 1.524121249013147, \"30d\": -1.024699508088499, \"90d\": -1.6826033901705457}",
#                 "createdAt": "2025-12-13T07:00:41.872042Z",
#                 "metricKey": "staking_wallets"
#             },
#             {
#                 "id": "693d0f19d757e0be21cbe202",
#                 "defaultValue": 2467075849793.0967,
#                 "changeAbsolutes": "{\"1y\": -397671492424.42725, \"7d\": 16798048725.992676, \"24h\": -71581536418.47607, \"30d\": -367999761570.0542, \"90d\": -852298728399.6538}",
#                 "changePercentages": "{\"1y\": -13.881555506273738, \"7d\": 0.6855569078198835, \"24h\": -2.819661164490451, \"30d\": -12.980245045144102, \"90d\": -25.67648538369213}",
#                 "createdAt": "2025-12-13T07:00:41.233515Z",
#                 "metricKey": "pos_assets_marketcap"
#             },
#             {
#                 "id": "693d0f19d757e0be21cbe203",
#                 "defaultValue": 1870000000.0,
#                 "changeAbsolutes": "{\"1y\": -219999999.99999976, \"7d\": 20000000, \"24h\": -50000000, \"30d\": -239999999.99999976, \"90d\": -520000000}",
#                 "changePercentages": "{\"1y\": -10.526315789473674, \"7d\": 1.0810810810810811, \"24h\": -2.604166666666667, \"30d\": -11.374407582938378, \"90d\": -21.75732217573222}",
#                 "createdAt": "2025-12-13T07:00:41.391826Z",
#                 "metricKey": "pow_assets_marketcap"
#             },
#             {
#                 "id": "693d0f19d757e0be21cbe205",
#                 "defaultValue": 340436318515.8608,
#                 "changeAbsolutes": "{\"1y\": -162131084266.39722, \"7d\": 2583197723.649353, \"24h\": -15280663327.562683, \"30d\": -60076091191.494934, \"90d\": -212593904421.06818}",
#                 "changePercentages": "{\"1y\": -32.26056512396647, \"7d\": 0.7645919379380508, \"24h\": -4.295736247500492, \"30d\": -14.999807680214209, \"90d\": -38.441643079118606}",
#                 "createdAt": "2025-12-13T07:00:41.716185Z",
#                 "metricKey": "staking_marketcap"
#             },
#             {
#                 "id": "693d011d34124c867a3eee8e",
#                 "defaultValue": 39604768971.05884,
#                 "changeAbsolutes": "{\"1y\": -113004522919.90268, \"7d\": 263631823.82000732, \"24h\": -1319171334.7939835, \"30d\": -5160955934.38604, \"90d\": -95050137927.45064}",
#                 "changePercentages": "{\"1y\": -74.04825847736963, \"7d\": 0.6701174468682342, \"24h\": -3.2234709681787885, \"30d\": -11.528811261935603, \"90d\": -70.58794968317844}",
#                 "createdAt": "2025-12-13T06:01:01.241542Z",
#                 "metricKey": "total_vsp_aum"
#             },
#             {
#                 "id": "693d011d34124c867a3eee8f",
#                 "defaultValue": 84,
#                 "changeAbsolutes": "{\"1y\": -3, \"7d\": 0, \"24h\": 0, \"30d\": 1, \"90d\": -9}",
#                 "changePercentages": "{\"1y\": -3.4482758620689653, \"7d\": 0, \"24h\": 0, \"30d\": 1.2048192771084338, \"90d\": -9.67741935483871}",
#                 "createdAt": "2025-12-13T06:01:01.402234Z",
#                 "metricKey": "total_vsps"
#             }
#         ]
#     }
# }

# %%
### Providers

query = """
{
  providers(limit: 5) {
    name
    logoUrl
    country
    rewardOptions(limit: 5) {
      id
      type {
        key
        label
      }
      metrics(limit: 2) {
        metricKey
        defaultValue
      }
    }
  }
}
"""
result = client.execute_raw_query(query)
print(json.dumps(result, indent=4))
# Out:
# {
#     "data": {
#         "providers": [
#             {
#                 "name": "Staked",
#                 "logoUrl": "https://storage.googleapis.com/stakingrewards-static/images/providers/production/eigenlayer/0x6573629204b65faac121c1b556b91a694d0e23c8.png",
#                 "country": "us",
#                 "rewardOptions": [
#                     {
#                         "id": "5d34930fe03dd8000780b7a3",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "30d_apr",
#                                 "defaultValue": 0.08998984800567686
#                             },
#                             {
#                                 "metricKey": "activation_time",
#                                 "defaultValue": 1532036007.0
#                             }
#                         ]
#                     },
#                     {
#                         "id": "5ef361ad97cfa00007ba4596",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 2250598.868104798
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             }
#                         ]
#                     },
#                     {
#                         "id": "5ef6218d41746e0008003c0f",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "lockup_time",
#                                 "defaultValue": 1239035.0
#                             },
#                             {
#                                 "metricKey": "minimum",
#                                 "defaultValue": 0
#                             }
#                         ]
#                     },
#                     {
#                         "id": "5ef622268105cb0007142f17",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 311043299.044154
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             }
#                         ]
#                     },
#                     {
#                         "id": "5ef62302b3a6250007455b00",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "minimum",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "reward_frequency",
#                                 "defaultValue": 604800
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "name": "Figment",
#                 "logoUrl": "https://storage.googleapis.com/stakingrewards-static/images/providers/production/figment_logo.png?random=0.725224064232785",
#                 "country": "CA",
#                 "rewardOptions": [
#                     {
#                         "id": "5f05c86c3ff67100084831e1",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 140523.69470203426
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             }
#                         ]
#                     },
#                     {
#                         "id": "5f884f4b79d36100077ec8f7",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 62745767.59978991
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             }
#                         ]
#                     },
#                     {
#                         "id": "5ff6d5221acf780007736bb8",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 2042889.9465273388
#                             },
#                             {
#                                 "metricKey": "bounty_per_month",
#                                 "defaultValue": 2481170.944958082
#                             }
#                         ]
#                     },
#                     {
#                         "id": "602cda8df12a3a0007b376ac",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 1661414531.2643225
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             }
#                         ]
#                     },
#                     {
#                         "id": "623b6166216825000900ba0d",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 12349019.640845858
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "name": "Chorus One",
#                 "logoUrl": "https://storage.googleapis.com/stakingrewards-static/images/providers/production/eigenlayer/0xf80b7ba7e778abf08a63426886ca40189c7ef48a.png",
#                 "country": "CH",
#                 "rewardOptions": [
#                     {
#                         "id": "1haw82vD6WDxtOk4bwj8PQ==",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 1867810.069330491
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             }
#                         ]
#                     },
#                     {
#                         "id": "5d34930fe03dd8000780b7bc",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 11917251.552802414
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             }
#                         ]
#                     },
#                     {
#                         "id": "5da99e27f72d5f00081e53de",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 4911612.685263445
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 445975.9188409995
#                             }
#                         ]
#                     },
#                     {
#                         "id": "5eda48e7ec338500073ed615",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             }
#                         ]
#                     },
#                     {
#                         "id": "5ff6d5221acf780007736bc3",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 5162895.9139638515
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "name": "Simple POS Pool",
#                 "logoUrl": "https://cms.stakingrewards.com/wp-content/uploads/2019/05/simplepospool.png",
#                 "country": null,
#                 "rewardOptions": null
#             },
#             {
#                 "name": "Stakinglab",
#                 "logoUrl": "https://cms.stakingrewards.com/wp-content/uploads/2019/05/stakinglab.png",
#                 "country": "de",
#                 "rewardOptions": null
#             }
#         ]
#     }
# }

# %%
query = """
{
  rewardOptions(
    where: {
      inputAsset: { symbols: ["ETH"] }
      typeKeys: ["solo-staking", "pos"]
    }
    limit: 10
  ) {
    metrics(limit: 10) {
      metricKey
      defaultValue
      changePercentages
      createdAt
    }
    providers(limit: 10) {
      name
    }
  }
}
"""
result = client.execute_raw_query(query)
print(json.dumps(result, indent=4))
# Out:
# {
#     "data": {
#         "rewardOptions": [
#             {
#                 "metrics": [
#                     {
#                         "metricKey": "hosting_fee",
#                         "defaultValue": 240,
#                         "changePercentages": "{\"1y\": 0, \"7d\": 0, \"24h\": 0, \"30d\": 0, \"90d\": 0}",
#                         "createdAt": "2023-07-20T13:33:59.991429Z"
#                     },
#                     {
#                         "metricKey": "lockup_time",
#                         "defaultValue": 3132672.0,
#                         "changePercentages": "{\"1y\": 2944.0298507462685, \"7d\": -22.186188477680275, \"24h\": -4.20385157350869, \"30d\": -50.85542168674699, \"90d\": -61.255699088145896}",
#                         "createdAt": "2025-12-13T00:01:16.950115Z"
#                     },
#                     {
#                         "metricKey": "minimum",
#                         "defaultValue": 32,
#                         "changePercentages": "{\"1y\": 0, \"7d\": 0, \"24h\": 0, \"30d\": 0, \"90d\": 0}",
#                         "createdAt": "2025-12-13T00:01:16.506179Z"
#                     },
#                     {
#                         "metricKey": "real_reward_rate",
#                         "defaultValue": 1.9546055693776099,
#                         "changePercentages": "{\"1y\": -34.45979247591634, \"7d\": 2.4859304554156667, \"24h\": -1.3153462411216892, \"30d\": -4.28046433378237, \"90d\": -9.08919584130556}",
#                         "createdAt": "2025-12-13T00:01:16.803005Z"
#                     },
#                     {
#                         "metricKey": "reward_frequency",
#                         "defaultValue": 12.091808173166635,
#                         "changePercentages": "{\"1y\": -0.40399328232879683, \"7d\": -0.009796603844011478, \"24h\": -0.002799029669718114, \"30d\": -0.1072961373390533, \"90d\": 0.020059712632954044}",
#                         "createdAt": "2023-11-14T12:19:54.683335Z"
#                     },
#                     {
#                         "metricKey": "reward_rate",
#                         "defaultValue": 2.798308035,
#                         "changePercentages": "{\"1y\": -13.522039840416022, \"7d\": 2.4998483751638334, \"24h\": -1.3262536792114366, \"30d\": -2.2637881188533977, \"90d\": -4.562694141707299}",
#                         "createdAt": "2025-12-13T00:01:16.656023Z"
#                     }
#                 ],
#                 "providers": null
#             }
#         ]
#     }
# }

# %%
## Validators
query = """
{
  providers(limit: 10) {
    name
    logoUrl
    country
    rewardOptions(limit: 5) {
      id
      input
      type {
        key
        label
      }
      metrics(limit: 10) {
        metricKey
        defaultValue
      }
    }
  }
}
"""
result = client.execute_raw_query(query)
print(json.dumps(result, indent=4))
# Out:
# {
#     "data": {
#         "providers": [
#             {
#                 "name": "Staked",
#                 "logoUrl": "https://storage.googleapis.com/stakingrewards-static/images/providers/production/eigenlayer/0x6573629204b65faac121c1b556b91a694d0e23c8.png",
#                 "country": "us",
#                 "rewardOptions": [
#                     {
#                         "id": "5d34930fe03dd8000780b7a3",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "30d_apr",
#                                 "defaultValue": 0.08998984800567686
#                             },
#                             {
#                                 "metricKey": "activation_time",
#                                 "defaultValue": 1532036007.0
#                             },
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 20790326.193907466
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 3661230.503659999
#                             },
#                             {
#                                 "metricKey": "available_delegation_capacity",
#                                 "defaultValue": 25086187.982741
#                             },
#                             {
#                                 "metricKey": "available_staking_capacity",
#                                 "defaultValue": 7797101.096441001
#                             },
#                             {
#                                 "metricKey": "baking_power",
#                                 "defaultValue": 35489982413494.0
#                             },
#                             {
#                                 "metricKey": "block_fees",
#                                 "defaultValue": 22715688.0
#                             },
#                             {
#                                 "metricKey": "block_rewards",
#                                 "defaultValue": 4025555365.0
#                             },
#                             {
#                                 "metricKey": "capacity",
#                                 "defaultValue": 13579097.84568
#                             }
#                         ]
#                     },
#                     {
#                         "id": "5ef361ad97cfa00007ba4596",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 2627048.2552264966
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "commission",
#                                 "defaultValue": 10
#                             },
#                             {
#                                 "metricKey": "daily_validator_revenue",
#                                 "defaultValue": 551.5834701083671
#                             },
#                             {
#                                 "metricKey": "delegated_tokens",
#                                 "defaultValue": 23516423.381546997
#                             },
#                             {
#                                 "metricKey": "lockup_time",
#                                 "defaultValue": 1814400.0
#                             },
#                             {
#                                 "metricKey": "minimum",
#                                 "defaultValue": 1e-05
#                             },
#                             {
#                                 "metricKey": "net_staking_flow",
#                                 "defaultValue": 34.323356788398165
#                             },
#                             {
#                                 "metricKey": "net_staking_flow_7d",
#                                 "defaultValue": -12210.423326042
#                             }
#                         ]
#                     },
#                     {
#                         "id": "5ef6218d41746e0008003c0f",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "lockup_time",
#                                 "defaultValue": 1239035.0
#                             },
#                             {
#                                 "metricKey": "minimum",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "reward_frequency",
#                                 "defaultValue": 86400
#                             },
#                             {
#                                 "metricKey": "reward_rate",
#                                 "defaultValue": 11.793236982236134
#                             }
#                         ]
#                     },
#                     {
#                         "id": "5ef622268105cb0007142f17",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 326239715.758264
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "candidate_reward",
#                                 "defaultValue": 35451876.679391496
#                             },
#                             {
#                                 "metricKey": "capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "commission",
#                                 "defaultValue": 10
#                             },
#                             {
#                                 "metricKey": "daily_validator_revenue",
#                                 "defaultValue": 1673.6422215426649
#                             },
#                             {
#                                 "metricKey": "delegated_tokens",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "lockup_time",
#                                 "defaultValue": 259200
#                             },
#                             {
#                                 "metricKey": "minimum",
#                                 "defaultValue": 1
#                             },
#                             {
#                                 "metricKey": "net_staking_flow",
#                                 "defaultValue": 29237.495812
#                             }
#                         ]
#                     },
#                     {
#                         "id": "5ef62302b3a6250007455b00",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "minimum",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "reward_frequency",
#                                 "defaultValue": 604800
#                             },
#                             {
#                                 "metricKey": "reward_rate",
#                                 "defaultValue": 42.27786171660726
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "name": "Figment",
#                 "logoUrl": "https://storage.googleapis.com/stakingrewards-static/images/providers/production/figment_logo.png?random=0.725224064232785",
#                 "country": "CA",
#                 "rewardOptions": [
#                     {
#                         "id": "5f05c86c3ff67100084831e1",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 155716.23729761783
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "commission",
#                                 "defaultValue": 10
#                             },
#                             {
#                                 "metricKey": "daily_validator_revenue",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "delegated_tokens",
#                                 "defaultValue": 389708.5556700006
#                             },
#                             {
#                                 "metricKey": "lockup_time",
#                                 "defaultValue": 1814400.0
#                             },
#                             {
#                                 "metricKey": "net_staking_flow",
#                                 "defaultValue": 0.30309458203783135
#                             },
#                             {
#                                 "metricKey": "net_staking_flow_7d",
#                                 "defaultValue": -105610.87474246
#                             },
#                             {
#                                 "metricKey": "oracle_status",
#                                 "defaultValue": 0
#                             }
#                         ]
#                     },
#                     {
#                         "id": "5f884f4b79d36100077ec8f7",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 63100949.955899894
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "commission",
#                                 "defaultValue": 10
#                             },
#                             {
#                                 "metricKey": "daily_validator_revenue",
#                                 "defaultValue": 436.3978943373541
#                             },
#                             {
#                                 "metricKey": "delegated_tokens",
#                                 "defaultValue": 36376847.8561606
#                             },
#                             {
#                                 "metricKey": "lockup_time",
#                                 "defaultValue": 172800
#                             },
#                             {
#                                 "metricKey": "net_staking_flow",
#                                 "defaultValue": -1201789.1446488523
#                             },
#                             {
#                                 "metricKey": "net_staking_flow_7d",
#                                 "defaultValue": -8835830.573432663
#                             },
#                             {
#                                 "metricKey": "other",
#                                 "defaultValue": 5
#                             }
#                         ]
#                     },
#                     {
#                         "id": "5ff6d5221acf780007736bb8",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 2211500.6592246927
#                             },
#                             {
#                                 "metricKey": "bounty_per_month",
#                                 "defaultValue": 2481170.944958082
#                             },
#                             {
#                                 "metricKey": "commission",
#                                 "defaultValue": 15
#                             },
#                             {
#                                 "metricKey": "daily_validator_revenue",
#                                 "defaultValue": 11924.479694963571
#                             },
#                             {
#                                 "metricKey": "delegated_tokens",
#                                 "defaultValue": 280000341.0
#                             },
#                             {
#                                 "metricKey": "id",
#                                 "defaultValue": 15
#                             },
#                             {
#                                 "metricKey": "minimum",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "monthly_rewards",
#                                 "defaultValue": 1519790.007925754
#                             },
#                             {
#                                 "metricKey": "net_staking_flow",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "net_staking_flow_7d",
#                                 "defaultValue": 0
#                             }
#                         ]
#                     },
#                     {
#                         "id": "602cda8df12a3a0007b376ac",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 1639940923.6591938
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "commission",
#                                 "defaultValue": 7.000000000000001
#                             },
#                             {
#                                 "metricKey": "daily_validator_revenue",
#                                 "defaultValue": 145.99581159515384
#                             },
#                             {
#                                 "metricKey": "delegated_tokens",
#                                 "defaultValue": 12398434.442119857
#                             },
#                             {
#                                 "metricKey": "lockup_time",
#                                 "defaultValue": 432000
#                             },
#                             {
#                                 "metricKey": "minimum",
#                                 "defaultValue": 1e-05
#                             },
#                             {
#                                 "metricKey": "net_staking_flow",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "net_staking_flow_7d",
#                                 "defaultValue": -1263578.348337707
#                             }
#                         ]
#                     },
#                     {
#                         "id": "623b6166216825000900ba0d",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 12220796.696124507
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "commission",
#                                 "defaultValue": 8
#                             },
#                             {
#                                 "metricKey": "daily_validator_revenue",
#                                 "defaultValue": 609.4553273918805
#                             },
#                             {
#                                 "metricKey": "delegated_tokens",
#                                 "defaultValue": 97969327.90114552
#                             },
#                             {
#                                 "metricKey": "lockup_time",
#                                 "defaultValue": 1814400.0
#                             },
#                             {
#                                 "metricKey": "net_staking_flow",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "net_staking_flow_7d",
#                                 "defaultValue": 855809.3177564782
#                             },
#                             {
#                                 "metricKey": "performance",
#                                 "defaultValue": 100
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "name": "Chorus One",
#                 "logoUrl": "https://storage.googleapis.com/stakingrewards-static/images/providers/production/eigenlayer/0xf80b7ba7e778abf08a63426886ca40189c7ef48a.png",
#                 "country": "CH",
#                 "rewardOptions": [
#                     {
#                         "id": "1haw82vD6WDxtOk4bwj8PQ==",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 1795095.6112009797
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "commission",
#                                 "defaultValue": 7.5
#                             },
#                             {
#                                 "metricKey": "daily_validator_revenue",
#                                 "defaultValue": 83.87373227306387
#                             },
#                             {
#                                 "metricKey": "delegated_tokens",
#                                 "defaultValue": 4065124.949904999
#                             },
#                             {
#                                 "metricKey": "lockup_time",
#                                 "defaultValue": 2145337344.0
#                             },
#                             {
#                                 "metricKey": "minimum",
#                                 "defaultValue": 1
#                             },
#                             {
#                                 "metricKey": "net_staking_flow",
#                                 "defaultValue": 605.6770529485929
#                             },
#                             {
#                                 "metricKey": "net_staking_flow_7d",
#                                 "defaultValue": 62788.40393540002
#                             }
#                         ]
#                     },
#                     {
#                         "id": "5d34930fe03dd8000780b7bc",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 12244396.991887901
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "commission",
#                                 "defaultValue": 7.5
#                             },
#                             {
#                                 "metricKey": "daily_validator_revenue",
#                                 "defaultValue": 213.84075458445912
#                             },
#                             {
#                                 "metricKey": "delegated_tokens",
#                                 "defaultValue": 5441934.218616845
#                             },
#                             {
#                                 "metricKey": "lockup_time",
#                                 "defaultValue": 1814400.0
#                             },
#                             {
#                                 "metricKey": "max_commission",
#                                 "defaultValue": 0.25
#                             },
#                             {
#                                 "metricKey": "max_commission_change",
#                                 "defaultValue": 0.02
#                             },
#                             {
#                                 "metricKey": "minimum",
#                                 "defaultValue": 0
#                             }
#                         ]
#                     },
#                     {
#                         "id": "5da99e27f72d5f00081e53de",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 4728020.601536761
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 445975.9188409995
#                             },
#                             {
#                                 "metricKey": "capacity",
#                                 "defaultValue": 17254342.195586998
#                             },
#                             {
#                                 "metricKey": "commission",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "delegated_tokens",
#                                 "defaultValue": 6086639.089163
#                             },
#                             {
#                                 "metricKey": "lockup_time",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "minimum",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "net_staking_flow_7d",
#                                 "defaultValue": -6697.325164019736
#                             },
#                             {
#                                 "metricKey": "performance",
#                                 "defaultValue": 95.79194501246306
#                             },
#                             {
#                                 "metricKey": "reward_frequency",
#                                 "defaultValue": 105317.37872117404
#                             }
#                         ]
#                     },
#                     {
#                         "id": "5eda48e7ec338500073ed615",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "commission",
#                                 "defaultValue": 14.999999999999998
#                             },
#                             {
#                                 "metricKey": "daily_validator_revenue",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "delegated_tokens",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "lockup_time",
#                                 "defaultValue": 604800
#                             },
#                             {
#                                 "metricKey": "minimum",
#                                 "defaultValue": 13.5
#                             },
#                             {
#                                 "metricKey": "net_staking_flow",
#                                 "defaultValue": 147072.63263361898
#                             },
#                             {
#                                 "metricKey": "net_staking_flow_7d",
#                                 "defaultValue": 0
#                             }
#                         ]
#                     },
#                     {
#                         "id": "5ff6d5221acf780007736bc3",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 5162895.9139638515
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "bounty_per_month",
#                                 "defaultValue": 945945.2707390641
#                             },
#                             {
#                                 "metricKey": "capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "commission",
#                                 "defaultValue": 9.526380033865461
#                             },
#                             {
#                                 "metricKey": "daily_validator_revenue",
#                                 "defaultValue": 3748.678004958075
#                             },
#                             {
#                                 "metricKey": "delegated_tokens",
#                                 "defaultValue": 252346889.0
#                             },
#                             {
#                                 "metricKey": "id",
#                                 "defaultValue": 52
#                             },
#                             {
#                                 "metricKey": "lockup_time",
#                                 "defaultValue": 5184000.0
#                             },
#                             {
#                                 "metricKey": "minimum",
#                                 "defaultValue": 0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "name": "Simple POS Pool",
#                 "logoUrl": "https://cms.stakingrewards.com/wp-content/uploads/2019/05/simplepospool.png",
#                 "country": null,
#                 "rewardOptions": null
#             },
#             {
#                 "name": "Stakinglab",
#                 "logoUrl": "https://cms.stakingrewards.com/wp-content/uploads/2019/05/stakinglab.png",
#                 "country": "de",
#                 "rewardOptions": null
#             },
#             {
#                 "name": "Cryptium Labs",
#                 "logoUrl": "https://cms.stakingrewards.com/wp-content/uploads/2019/09/cryptium-labs.jpg",
#                 "country": "ch",
#                 "rewardOptions": null
#             },
#             {
#                 "name": "P2P.org",
#                 "logoUrl": "https://storage.googleapis.com/stakingrewards-static/images/providers/production/p2p-validator_logo.png?v=1757943869212",
#                 "country": "KY",
#                 "rewardOptions": [
#                     {
#                         "id": "5d349310e03dd8000780b7d2",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 12583477.782670252
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "commission",
#                                 "defaultValue": 8
#                             },
#                             {
#                                 "metricKey": "daily_validator_revenue",
#                                 "defaultValue": 198.86086521808684
#                             },
#                             {
#                                 "metricKey": "delegated_tokens",
#                                 "defaultValue": 5338434.96667589
#                             },
#                             {
#                                 "metricKey": "lockup_time",
#                                 "defaultValue": 1814400.0
#                             },
#                             {
#                                 "metricKey": "max_commission",
#                                 "defaultValue": 0.5
#                             },
#                             {
#                                 "metricKey": "max_commission_change",
#                                 "defaultValue": 0.01
#                             },
#                             {
#                                 "metricKey": "minimum",
#                                 "defaultValue": 0
#                             }
#                         ]
#                     },
#                     {
#                         "id": "5f22c6d49de13d000815143b",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 2618732.7080832687
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "commission",
#                                 "defaultValue": 14.999999999999998
#                             },
#                             {
#                                 "metricKey": "delegated_tokens",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "lockup_time",
#                                 "defaultValue": 604800
#                             },
#                             {
#                                 "metricKey": "minimum",
#                                 "defaultValue": 13.5
#                             },
#                             {
#                                 "metricKey": "net_staking_flow_7d",
#                                 "defaultValue": 262367.6396053149
#                             },
#                             {
#                                 "metricKey": "performance",
#                                 "defaultValue": 29.399803632531853
#                             },
#                             {
#                                 "metricKey": "points_30d",
#                                 "defaultValue": 3467920.0
#                             }
#                         ]
#                     },
#                     {
#                         "id": "60103eec2993b30008207506",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 18375684.184827726
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "commission",
#                                 "defaultValue": 7.000000000000001
#                             },
#                             {
#                                 "metricKey": "daily_validator_revenue",
#                                 "defaultValue": 89.8824139491524
#                             },
#                             {
#                                 "metricKey": "delegated_tokens",
#                                 "defaultValue": 10620695.28610955
#                             },
#                             {
#                                 "metricKey": "lockup_time",
#                                 "defaultValue": 172800
#                             },
#                             {
#                                 "metricKey": "net_staking_flow",
#                                 "defaultValue": 3210.9875884357093
#                             },
#                             {
#                                 "metricKey": "net_staking_flow_7d",
#                                 "defaultValue": 15232.815425980723
#                             },
#                             {
#                                 "metricKey": "performance",
#                                 "defaultValue": 100
#                             }
#                         ]
#                     },
#                     {
#                         "id": "602cda2ef12a3a0007b37480",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 1150269705.8483145
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "commission",
#                                 "defaultValue": 7
#                             },
#                             {
#                                 "metricKey": "daily_validator_revenue",
#                                 "defaultValue": 1118.7122732101964
#                             },
#                             {
#                                 "metricKey": "delegated_tokens",
#                                 "defaultValue": 3415820.099361613
#                             },
#                             {
#                                 "metricKey": "lockup_time",
#                                 "defaultValue": 432000
#                             },
#                             {
#                                 "metricKey": "minimum",
#                                 "defaultValue": 1e-05
#                             },
#                             {
#                                 "metricKey": "net_staking_flow",
#                                 "defaultValue": 2053847.002003211
#                             },
#                             {
#                                 "metricKey": "net_staking_flow_7d",
#                                 "defaultValue": -300459.80394995
#                             }
#                         ]
#                     },
#                     {
#                         "id": "6066ead982ef2700083e4d0f",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 76879.71616293915
#                             },
#                             {
#                                 "metricKey": "commission",
#                                 "defaultValue": 0.1
#                             },
#                             {
#                                 "metricKey": "staked_tokens",
#                                 "defaultValue": 5788616.544371337
#                             },
#                             {
#                                 "metricKey": "staking_wallets",
#                                 "defaultValue": 166
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "name": "Zednode",
#                 "logoUrl": "https://cms.stakingrewards.com/wp-content/uploads/2019/05/zednode.svg",
#                 "country": "us",
#                 "rewardOptions": null
#             },
#             {
#                 "name": "Staking Facilities",
#                 "logoUrl": "https://storage.googleapis.com/stakingrewards-static/images/providers/production/staking_facilities_logo.png?random=0.6196942809149235",
#                 "country": "DE",
#                 "rewardOptions": [
#                     {
#                         "id": "602cda16f12a3a0007b373f0",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 888564567.0944046
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "commission",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "daily_validator_revenue",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "delegated_tokens",
#                                 "defaultValue": 6717808.778214293
#                             },
#                             {
#                                 "metricKey": "lockup_time",
#                                 "defaultValue": 432000
#                             },
#                             {
#                                 "metricKey": "minimum",
#                                 "defaultValue": 1e-05
#                             },
#                             {
#                                 "metricKey": "net_staking_flow",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "net_staking_flow_7d",
#                                 "defaultValue": 4346332.930769675
#                             }
#                         ]
#                     },
#                     {
#                         "id": "64cb739ce7bc370008006c46",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 18829204.07538265
#                             },
#                             {
#                                 "metricKey": "available_capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "capacity",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "commission",
#                                 "defaultValue": 0.9745133117977111
#                             },
#                             {
#                                 "metricKey": "delegated_tokens",
#                                 "defaultValue": 2049373.21299027
#                             },
#                             {
#                                 "metricKey": "is_delegation_node",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "is_not_delegation_node",
#                                 "defaultValue": 1
#                             },
#                             {
#                                 "metricKey": "net_staking_flow",
#                                 "defaultValue": 6641.441335985949
#                             },
#                             {
#                                 "metricKey": "net_staking_flow_7d",
#                                 "defaultValue": -17952112.27785013
#                             },
#                             {
#                                 "metricKey": "performance",
#                                 "defaultValue": 19.49026549045871
#                             }
#                         ]
#                     },
#                     {
#                         "id": "656f656717b79c878a889817",
#                         "type": {
#                             "key": "operator",
#                             "label": "operator"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 748783254.0199324
#                             },
#                             {
#                                 "metricKey": "commission",
#                                 "defaultValue": 5
#                             },
#                             {
#                                 "metricKey": "net_staking_flow",
#                                 "defaultValue": -542596.9759483429
#                             },
#                             {
#                                 "metricKey": "performance",
#                                 "defaultValue": 96.896178167
#                             },
#                             {
#                                 "metricKey": "reward_rate",
#                                 "defaultValue": 2.85
#                             },
#                             {
#                                 "metricKey": "staked_tokens",
#                                 "defaultValue": 247743.77202958314
#                             },
#                             {
#                                 "metricKey": "staking_share",
#                                 "defaultValue": 0.006202595
#                             },
#                             {
#                                 "metricKey": "staking_wallets",
#                                 "defaultValue": 6909
#                             }
#                         ]
#                     },
#                     {
#                         "id": "65a796d3c70166bcb2f84631",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 4286785.326661441
#                             },
#                             {
#                                 "metricKey": "commission",
#                                 "defaultValue": 10
#                             },
#                             {
#                                 "metricKey": "daily_validator_revenue",
#                                 "defaultValue": 119.07367017038065
#                             },
#                             {
#                                 "metricKey": "delegated_tokens",
#                                 "defaultValue": 7242534.7892729975
#                             },
#                             {
#                                 "metricKey": "net_staking_flow",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "performance",
#                                 "defaultValue": 99.96043171964749
#                             },
#                             {
#                                 "metricKey": "reward_rate",
#                                 "defaultValue": 5.4104243294286
#                             },
#                             {
#                                 "metricKey": "self_staked_tokens",
#                                 "defaultValue": 79045.614931
#                             },
#                             {
#                                 "metricKey": "staked_tokens",
#                                 "defaultValue": 7321580.404203998
#                             },
#                             {
#                                 "metricKey": "staking_share",
#                                 "defaultValue": 0.016627279235129043
#                             }
#                         ]
#                     },
#                     {
#                         "id": "65b91e1f8febffe17bd5240d",
#                         "type": {
#                             "key": "pos",
#                             "label": "pos"
#                         },
#                         "metrics": [
#                             {
#                                 "metricKey": "assets_under_management",
#                                 "defaultValue": 13088.42866286391
#                             },
#                             {
#                                 "metricKey": "commission",
#                                 "defaultValue": 10
#                             },
#                             {
#                                 "metricKey": "daily_validator_revenue",
#                                 "defaultValue": 530.2479936882094
#                             },
#                             {
#                                 "metricKey": "delegated_tokens",
#                                 "defaultValue": 306365.2381505164
#                             },
#                             {
#                                 "metricKey": "net_staking_flow",
#                                 "defaultValue": 0
#                             },
#                             {
#                                 "metricKey": "performance",
#                                 "defaultValue": 99.89598379393688
#                             },
#                             {
#                                 "metricKey": "reward_rate",
#                                 "defaultValue": 36.47327483316115
#                             },
#                             {
#                                 "metricKey": "self_staked_tokens",
#                                 "defaultValue": 500000
#                             },
#                             {
#                                 "metricKey": "staked_tokens",
#                                 "defaultValue": 806365.2381505164
#                             },
#                             {
#                                 "metricKey": "staking_share",
#                                 "defaultValue": 0.00683583533726906
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "name": "StackOfStake",
#                 "logoUrl": "https://cms.stakingrewards.com/wp-content/uploads/2019/09/stackofstake.jpg",
#                 "country": "ua",
#                 "rewardOptions": null
#             }
#         ]
#     }
# }

# %%
response = client.get_total_staked_tokens(asset_slug="solana")
print(response)
# Out:
# {'data': {'assets': [{'slug': 'solana', 'metrics': [{'metricKey': 'staked_tokens', 'defaultValue': 413847099.60055584, 'createdAt': '2025-12-13T23:12:40.51053Z'}]}]}}

# %%
resp = client.get_provider_staked_tokens(asset_slug="solana", is_active=True, limit=200)
rows = []
for ro in resp["data"]["rewardOptions"]:
    provider = (ro.get("providers") or [{}])[0].get("slug")
    staked = (ro.get("metrics") or [{}])[0].get("defaultValue")
    rows.append({"provider": provider, "staked_tokens": staked})
print(rows)
# Out:
# [{'provider': 'helius', 'staked_tokens': 14504570.626189446}, {'provider': 'jito-network', 'staked_tokens': 13979696.39345446}, {'provider': 'figment-networks', 'staked_tokens': 12612642.158794}, {'provider': 'jupiter', 'staked_tokens': 12324602.059314724}, {'provider': 'binance-staking', 'staked_tokens': 11488304.643743591}, {'provider': 'kiln', 'staked_tokens': 9925163.503647417}, {'provider': 'p2p-validator', 'staked_tokens': 8822384.474408738}, {'provider': 'binance-staking', 'staked_tokens': 8557431.78426265}, {'provider': 'ledger-by-figment', 'staked_tokens': 8344204.153818233}, {'provider': 'galaxy', 'staked_tokens': 7810165.129446761}, {'provider': 'staking-facilities', 'staked_tokens': 6729681.510437311}, {'provider': 'everstake', 'staked_tokens': 6495294.608558527}, {'provider': 'coinbase', 'staked_tokens': 5874598.229793491}, {'provider': 'staked', 'staked_tokens': 5470420.556981863}, {'provider': 'chorus-one', 'staked_tokens': 3906489.680090907}, {'provider': 'upbit-staking', 'staked_tokens': 3876482.3542656}, {'provider': 'marinade', 'staked_tokens': 3525762.318535342}, {'provider': 'twinstake', 'staked_tokens': 3479979.268627853}, {'provider': 'kraken', 'staked_tokens': 2791045.814471746}, {'provider': 'okxearn', 'staked_tokens': 2028381.361838764}, {'provider': 'blockdaemon', 'staked_tokens': 2027199.655757994}, {'provider': 'shinobi-systems', 'staked_tokens': 1926869.539988958}, {'provider': 'bybit', 'staked_tokens': 1593567.295054389}, {'provider': 'melea', 'staked_tokens': 1444753.875186429}, {'provider': 'luganodes', 'staked_tokens': 1400478.978428066}, {'provider': 'solana-compass', 'staked_tokens': 1365653.310455094}, {'provider': 'nansen', 'staked_tokens': 1356777.523709297}, {'provider': 'solayer', 'staked_tokens': 1196771.628761535}, {'provider': 'pumpkins-pool', 'staked_tokens': 1145303.125214741}, {'provider': 'solblaze', 'staked_tokens': 1141662.897591439}, {'provider': 'stakewolf', 'staked_tokens': 824881.369259752}, {'provider': 'jump-crypto', 'staked_tokens': 813712.249182791}, {'provider': 'coinbase-cloud', 'staked_tokens': 762947.827249602}, {'provider': 'cogent-crypto', 'staked_tokens': 759013.934457182}, {'provider': 'allnodes', 'staked_tokens': 677248.462287837}, {'provider': 'stake-fish', 'staked_tokens': 670147.064448086}, {'provider': 'solana-beach-validator', 'staked_tokens': 612476.808773695}, {'provider': 'laine', 'staked_tokens': 611735.505542365}, {'provider': 'chainflow', 'staked_tokens': 541191.076183584}, {'provider': 'validator-com', 'staked_tokens': 533535.084835839}, {'provider': 'solayer', 'staked_tokens': 521793.34041936}, {'provider': 'rockawayx', 'staked_tokens': 509190.668634778}, {'provider': 'sanctum', 'staked_tokens': 460841.390607378}, {'provider': 'stardust-staking', 'staked_tokens': 429935.328595962}, {'provider': 'chainode-tech', 'staked_tokens': 425016.419732352}, {'provider': 'jito-labs', 'staked_tokens': 362750.924651103}, {'provider': 'globalstake', 'staked_tokens': 318791.32403311}, {'provider': 'ubik-capital', 'staked_tokens': 314472.384009785}, {'provider': 'Phantom', 'staked_tokens': 307290.649591101}]

# %%
resp = client.get_provider_stake_shares(
    asset_slug="cosmos",
    limit=200,
    is_active=True,          # set to None to include inactive
    include_reward_rate=True
)
print("Total staked tokens:", resp["total_staked_tokens"])
for p in resp["providers"]:
    print(p["provider"], p["staked_tokens"], p["reward_rate"], p["share"])
# Out:
# Total staked tokens: 285435052.7801263
# coinbase01 48268026.063826 16.230981764111274 0.169103358517804
# upbit-staking 17405508.94059199 0 0.06097887687956687
# cosmostation 13336247.637308752 19.253292130850717 0.04672252937196823
# kiln 13067733.47594701 18.612676732560313 0.04578181042821404
# everstake 11230693.991902694 18.664542464341938 0.03934588230322861
# staked 10121270.471168058 18.243433021412965 0.035459101370302205
# binance-staking 9678881.213031992 19.269068065760237 0.03390922424824865
# dokia-capital 8634544.965622906 17.24490606869142 0.03025047162751307
# ledger 8369748.1958840005 18.753014636717758 0.029322776282600823
# drop 6870061.906460027 15.149691197271922 0.024068739419163456
# sg-1 6790815.754227 19.25977861783628 0.02379110655150697
# allnodes 6648503.394219 19.262330812101894 0.02329252602111351
# blockdaemon 5888427.971883995 18.255005188513078 0.020629659582910145
# p2p-validator 5626509.337171888 18.665171912040055 0.019712047565181315
# cloudbyte 5623559.634779995 19.273496018224222 0.019701713507177004
# chorus-one 5510045.750147846 18.752635785683065 0.019304026245130775
# figment-networks 5018277.699583759 18.427473522241634 0.01758115427907655
# stake-fish 4832356.653806861 19.271755555194677 0.016929794034544445
# cephalopod-equipment 4244277.751955004 19.264116411444686 0.014869504325470557
# stride 3994468.5780062163 15.144204763771896 0.013994316882598154
# ccn 3980741.8811709504 19.030885838703952 0.013946226444154913
# nansen 3940771.957898357 19.243555456857937 0.013806194857693167
# keplr 3809163.4781869794 19.255259460079788 0.01334511455788585
# melea 3225973.131431995 18.87265232437343 0.011301951529817878
# sikka 3131763.2262935 19.25786795484559 0.010971894291854656
# imperator 2854891.694616545 19.270926938576398 0.010001895936781455
# okex-pool 2702171.055225998 19.253039785897606 0.009466850791123787
# provalidator 2669034.2159259766 19.262955584700112 0.009350758394702008
# swiss-staking 2387174.6106109777 19.25307857978326 0.008363284702982308
# posthuman-dvs 2205107.9355350444 19.268363525473024 0.007725427953075066
# boubounode 2125102.852638985 0.5176560051253993 0.007445136229557534
# pro-delegators 2048052.350529023 19.271702988159216 0.007175195655127403
# stakecito 1892050.57471699 19.26753668035625 0.006628655297548396
# coinone-node 1873816.6074319824 18.214629854366017 0.006564773979863657
# iqlusion 1732292.9413170659 18.17901326268246 0.006068956578544227
# citadel 1653404.6267839852 19.264304309844416 0.0057925773680558455
# pryzm-stakedrop 1634643.9252441355 16.228437783229364 0.0057268506769675535
# polkachucom 1582172.2702410314 19.268873564727865 0.005543020224148139
# nodestake 1563888.5407970273 19.26761355209295 0.005478964568523781
# meria 1422632.9099650034 19.1872200264798 0.004984086208433808
# stakelab 1388365.3021440122 19.237934428692952 0.004864032250494073
# spark-pool 1348973.4572519974 19.19607568913009 0.004726025917675663
# lavenderfive-nodes 1166017.6328820132 19.274231161957427 0.004085054100836765
# stakely 1156012.9857469967 19.272569547411717 0.004050003580455432
# kahuna 1122314.0935940004 19.274189759800723 0.003931942074607534
# coinbase-custody 1046000.8645480005 16.22538663467397 0.003664584480287172
# enigma 976415.5795959989 19.274122242055476 0.0034207977264381134
# high-stakes-switzerland 961093.7721469348 19.2733918917697 0.0033671189392680363
# blockhunters 947002.8165259875 19.238055346269046 0.0033177523478711427
# twinstake 929710.1796789812 18.661747088058274 0.003257168909787499
# cexio 835303.7302459985 19.27134803748973 0.0029264230938357877
# ubik-capital 830342.8176319838 19.27241318032387 0.0029090429137713716
# dkcmc 800434.5557090002 19.27422060112822 0.0028042615926558386
# thecybernetics 799173.7563029992 19.272206706959725 0.0027998444778210597
# shapeshift-dao 775728.6825729941 18.24207216338667 0.0027177064450123662
# atomicnodes 757282.3628659871 18.226977366120124 0.002653081166766613
# simply-staking 735924.2109470001 18.216803689280844 0.002578254505811837
# cryptocrew-validators 645046.0347509924 19.270703219725693 0.0022598697268197063
# interstellar-lounge 614461.2018790024 0 0.002152718090837738
# coinbase-cloud 609059.9272820004 18.6406873256421 0.0021337951360555774
# binary-builders 605674.705932991 19.260644953295337 0.002121935270506348
# leap-wallet 602371.5243730024 19.260854656183863 0.0021103628251188046
# cosmosrescue 601406.5104809967 19.211875887434438 0.0021069819723377376
# eco-stake 571159.8078019983 19.271764460207706 0.0020010149497720203
# bunkerstakeio 569985.4650740036 18.2577987864676 0.0019969007293335816
# golden-ratio-staking 558530.4410220016 19.27263809517867 0.0019567689237251587
# forbole 547522.0821330053 18.322958923533125 0.0019182019755463163
# node-guardians 547372.3913700008 19.270703473747105 0.0019176775453421543
# stakin 537305.7863010016 19.26369271246658 0.0018824099600510315
# mantra-dao 526468.8918669996 19.200974869237715 0.0018444437245503421
# quasar 523569.1330750001 19.263381511955 0.0018342846401500346
# colossus 516089.5221050021 18.25679665910831 0.0018080803919431419
# jerrys-pool 509876.91796200525 19.273025866235002 0.0017863150057984259
# croutondigital 497343.16073799244 19.271499882124974 0.0017424039405598208
# stake-zone 496044.0373980048 19.18976663246798 0.0017378525607368654
# 0base-vc 468430.6330960049 19.247425545795565 0.001641111098771888
# 01node 456815.08452700655 19.270350743591344 0.0016004169077261025
# infstones 441871.25758800335 18.15047730822277 0.001548062346527501
# cryptostakecom 438807.4280360057 19.27064931981921 0.001537328452697167
# cros-nest 429406.43810100335 19.27396316953435 0.001504392799407786
# decentralizehk 401973.23103500553 19.130888906196024 0.001408282644755092
# moonletwallet 401775.66859000176 19.273490761338184 0.0014075904997537002
# dora-factory 399667.03142400325 0 0.0014002030498050677
# stir 395108.4790500013 19.137603300574497 0.001384232508241928
# biglazycatcom 378389.69091399974 19.266470015398777 0.0013256595054759355
# node101 366621.2618709998 19.26701919138348 0.001284429709316088
# westaking 366223.5843100037 18.93398407131243 0.0012830364762246272
# witval 335735.105236002 19.25726344890402 0.001176222408446178
# citizen-cosmos 334338.2699280034 18.22041339757622 0.0011713287021743186
# cosmic-validator 320674.3807820034 18.245870849554834 0.0011234583056938783
# silk-nodes 320560.55600700213 19.25378336012401 0.0011230595292510673
# gata-hub 312332.979509 19.176958232007017 0.0010942348406997983
# stakewolle 306353.97729400446 19.07303186050971 0.0010732878611443434
# whispernode 303119.5352569985 0 0.0010619562394479096
# frens 297924.4529240079 19.247801599339905 0.0010437556635817338
# onbloc-node 297195.83758200135 18.440867289975646 0.0010412030151424132
# blockpower 276608.83546200313 19.25651763028531 0.0009690780188622381
# stakesystems 263468.5085410035 19.271408707982914 0.0009230418828200339
# kalpatech 257113.96683300185 18.258239568980652 0.0009007792292107149
# blocks-united 255498.24138500082 19.26729428281117 0.000895118657980013
# oni 254102.39329900476 19.26730884616262 0.0008902284103653611
# sygnum 253281.06683000474 18.259130123111525 0.000887350955543326
# multichain-ventures 234324.80946400165 18.15252520345466 0.0008209391494901806
# irisnet-bianjie 229937.4072770035 18.39513186538423 0.0008055682195911894
# chill-validation 229934.18032900113 19.23749628793465 0.0008055569142242733
# jabbey 223127.39071500063 19.250909736076828 0.0007817098444698664
# cosmos-spaces 222223.67537700268 18.258801834746333 0.0007785437465109936
# mailanderli 222038.49382300163 18.257170383488944 0.0007778949770196595
# stakerelax 217995.60150200213 19.271653362799423 0.0007637310112361235
# tienthuattoan 208368.88548295357 18.250895791552274 0.0007300045437778183
# skystar-capital 204810.50956200255 18.24644052168886 0.0007175380443542452
# huginn 203913.9907059999 19.26213160223936 0.0007143971587227482
# w3coins 202185.58480700155 19.271492061136517 0.000708341820101357
# dsrv 195562.3716520028 18.23322860392567 0.0006851378965100219
# a41 194114.97923500315 0 0.0006800670672516597
# ethicalnode 192392.5460099998 19.215299542424827 0.0006740326534393863
# mitera-net 186500.25396700227 19.242740724096986 0.0006533894563771936
# republic-crypto 176672.0638510037 19.260216750654035 0.0006189571397423851
# freak12techno 176073.7246540025 19.23163353671073 0.0006168609038695539
# ezstakingio 174142.4090630019 19.256583908843865 0.0006100946865735712
# commons-hub 173394.86251400068 18.212461887067953 0.0006074757140902685
# easy-2-stake 171875.68732900277 19.2721501574325 0.0006021533993633238
# xprv 164664.072434 19.26379967957536 0.0005768880550240006
# defi-wallet 162996.0790830014 18.850788300582064 0.0005710443671701354
# zkvalidator 161200.4606229997 19.270422164315132 0.0005647535544528029
# tessellated-geometry 160480.8890530013 19.110093615328907 0.0005622325901809315
# chiter-in-cosmos 159320.99505099986 19.23072598254628 0.0005581689897551811
# cosmosvaloper146kwpzhmleafmhtaxulfptyhnvwxzlvm87hwnm 153350.05728100165 19.22344576300228 0.0005372502633694708
# neopin 152513.52943400363 19.254604267838324 0.0005343195516756888
# alessandro-mazza 152484.28869100008 18.25078542468301 0.0005342171089563425
# kintsugi-nodes 150715.16141400306 18.257571899514367 0.000528019106084005
# terranodes 143210.39260699993 19.255693601580013 0.0005017267193084252
# hashquark 141148.74736799992 19.244371207158846 0.0004945039020022826
# cryptodungeon 138418.6518949999 19.270672936496386 0.00048493922013714727
# stakeflow 136840.87998300148 18.864999505061107 0.0004794116162334536
# coinbase-new 136016.62290800002 18.658795503561258 0.0004765238942561659
# dragonstake 135769.08645200063 18.452808958928262 0.00047565666910778836
# kjnodes 133227.89452800003 18.247677497749187 0.00046675379646040504
# rockx 128464.9556259991 0 0.00045006720224007333
# cypher-core 124493.40779399962 18.22640281957838 0.0004361531864479807
# ping-pub 122060.62885599917 19.193742623989518 0.0004276301304522111
# allnodes 118285.958188 18.260889724243842 0.0004144058588316305
# cosmos-af 118285.95818799995 18.254798015499098 0.0004144058588316303
# compass 117816.28657299935 18.240753292939296 0.00041276040004713265
# astroport 114034.12748254908 6.492187781759571 0.0003995098933079912
# atlas-staking-validator 106454.24727600002 16.143042227459272 0.000372954359456345
# big-brain-staking 103261.52375299994 18.239262575748903 0.0003617688954010264
# smartnodes 93662.85249600025 19.002871456416102 0.00032814068063374743
# nylira-net 93128.26787700056 18.19604043019691 0.00032626780407639096
# crowdcontrol 92646.26404799947 19.2512676066656 0.000324579140318011
# voidstake 92388.19886100001 19.270697331058557 0.0003236750285612876
# b-harvest 82359.79304599998 18.258766751538207 0.00028854127145148717
# ztake 80417.30861999959 18.868360046835043 0.0002817359249914758
# chainflow 77078.65790900026 18.657327047343898 0.00027003921613080506
# blockscape 73972.40979499913 19.273659817811346 0.0002591567120944353
# dforce 62489.834514999486 19.09359629158883 0.00021892838285400107
# replicator-network 61546.89775 19.080351110108243 0.00021562487560842865
# daic 59839.16393899924 19.268641609710343 0.00020964196007521895
# xilodyne 56940.227536 19.172945706956774 0.000199485756852231
# white-whale 54766.75374400002 18.842858519349452 0.00019187115671524566
# umbrella 51265.55528199931 18.220531549880327 0.00017960497417074324
# cosmosvaloper1rcp29q3hpd246n6qak7jluqep4v006cdsc2kkl 49118.90311499993 0 0.0001720843415571554
# cosmicnode 48084.43853299999 19.27112643104826 0.00016846017356543787
# huobi 46437.0843429999 18.712764186232015 0.000162688793442517
# expedition-by-life-and-crypto 45494.43160099996 19.24898399790763 0.0001593862812499235
# syncnode 34781.732430000244 19.268322187424406 0.00012185515440807822
# chainlayer 32206.715400000558 18.24003859798323 0.00011283377807423583
# synclub 30736.616265000153 19.270632425603075 0.00010768339755621011
# lunamint 29264.402769000928 17.226288686027925 0.00010252560953522276
# commercio-network 25992.56445600067 18.45988536097564 9.10629728298403e-05
# owallet 25391.77461600001 19.258297459047462 8.895815131563245e-05
# staking-fund 19197.93666600068 18.2529384924366 6.725851110090904e-05
# inter-blockchain-services 15744.346874 19.259313623526488 5.5159121911099134e-05
# nexusecurus 11195.766281 18.257446103503817 3.922351572434315e-05
# ateam 11150.83117199979 0 3.906608898728845e-05
# snow-fall 9795.259086 19.274014456631306 3.4316945275622454e-05
# cosmosvaloper1ul2me6vukg2vac2p6ltxmqlaa7jywdgt8q76ag 6543.736058000065 19.2144439655425 2.2925481626255538e-05
# astrovault 4768.123826000002 18.58768448545072 1.670475920724754e-05
# apeiron-nodes 4204.253909 228.59982026946625 1.4729283835502091e-05
# when-moon-when-lambo-restake 3118.259399 19.272088214442558 1.0924584659901702e-05
# chaintools 3040.047137 19.026726961402144 1.0650573948048986e-05
# delight 2356.8094669999996 19.22670261626855 8.256902731618865e-06
# navs 2292 19.273519873248343 8.029847692762361e-06
# the-chicken-coop 2250.840536 19.273061275621572 7.885648640827051e-06
# itrocket 2203.325168 19.274286724686437 7.719182162596005e-06
# positiva-ultra 1084.69481 19.274259971975045 3.8001457754929355e-06
# nodeasy 625.4068249999996 8.149496416254246 2.191065249024468e-06
# sr20de 599.4299850000001 18.903827199967413 2.1000573656303787e-06
# doubletop 372.283661 0 1.304267494037511e-06
# solidaritynode 356.325676 19.2427087274708 1.2483599071992098e-06
# cactus 350.260061 19.244076196375374 1.227109486338418e-06
# csaxial 305.630372 19.167793938805723 1.0707527650271826e-06
# validarios 145.735823 19.270953490792802 5.105743726306169e-07
# luckystar 127.288083 18.259854484625183 4.459441184963761e-07
# gelotto-slash-protected 112.755115 8.008322489367343 3.950289703446356e-07
# post-road 110.51744899999987 7.55069423884999 3.87189477688757e-07
# the-silver-fox 107.75432500000001 19.274290844882135 3.7750908289110635e-07

# %%
import matplotlib.pyplot as plt


def plot_lorenz_curve(stake_shares_response, ax=None, title="Lorenz curve"):
    """
    Plot a Lorenz curve from a get_provider_stake_shares response.
    - stake_shares_response: dict returned by client.get_provider_stake_shares
    - ax: optional matplotlib axes
    - title: plot title
    """
    providers = stake_shares_response.get("providers") or []
    staked = [p.get("staked_tokens") for p in providers if p.get("staked_tokens") not in (None, 0)]
    if not staked:
        raise ValueError("No staked_tokens values in response")

    staked_sorted = sorted(staked)
    n = len(staked_sorted)
    total = sum(staked_sorted)
    cumulative = []
    running = 0.0
    for v in staked_sorted:
        running += v
        cumulative.append(running / total)

    x = [0.0] + [i / n for i in range(1, n + 1)]  # cumulative share of providers
    y = [0.0] + cumulative  # cumulative share of staked tokens

    # Gini = 1 - 2 * area under Lorenz curve
    area = 0.0
    for i in range(1, len(x)):
        width = x[i] - x[i - 1]
        height = (y[i] + y[i - 1]) / 2
        area += width * height
    gini = 1 - 2 * area

    if ax is None:
        fig, ax = plt.subplots(figsize=(6, 6))
    ax.plot(x, y, label="Lorenz")
    ax.plot([0, 1], [0, 1], "k--", label="Equality")
    ax.fill_between(x, y, x, alpha=0.1)
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.set_xlabel("Cumulative share of providers")
    ax.set_ylabel("Cumulative share of staked tokens")
    ax.set_title(title)
    ax.legend()
    ax.text(0.6, 0.1, f"Gini: {gini:.3f}", transform=ax.transAxes)
    return ax


# Example usage (uncomment to run)
# resp = client.get_provider_stake_shares(asset_slug="solana", limit=200, is_active=True)
# plot_lorenz_curve(resp, title="Solana provider staked tokens")
# plt.show()

# %%
resp = client.get_provider_stake_shares(
    asset_slug="cosmos",
    limit=200,
    is_active=True,          # set to None to include inactive
    include_reward_rate=True
)

# %%
plot_lorenz_curve(resp, title="Cosmos HUB provider staked tokens")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 plot_lorenz_curve(resp, title="Cosmos HUB provider staked tokens")
#
# Cell In[10], line 18, in plot_lorenz_curve(stake_shares_response, ax, title)
#      16 staked_sorted = sorted(staked)
#      17 n = len(staked_sorted)
# ---> 18 total = sum(staked_sorted)
#      19 cumulative = []
#      20 running = 0.0
#
# TypeError: 'float' object is not callable

# %%
resp_solana = client.get_provider_stake_shares(
    asset_slug="ethereum-2-0",
    limit=200,
    is_active=True,          # set to None to include inactive
    include_reward_rate=True
)
print("Total staked tokens:", resp_solana["total_staked_tokens"])
for p in resp_solana["providers"]:
    print(p["provider"], p["staked_tokens"], p["reward_rate"], p["share"])
# Out:
# Total staked tokens: 35694110.50793164
# velora 32484682.851145755 4.9928203802313 0.9100852322381667
# lido-finance 8770038.518973408 2.5367142857142855 0.24569987581073366
# binance-staking 3074123.049113074 2.5411300000000003 0.08612409737539106
# ether-fi 3066251.182771556 3.0000944718536124 0.08590356053529334
# p2p-validator 929170 2.66109322485 0.026031465325169756
# bitcoin-suisse-ag 703891.175951683 2.83 0.019720092921079242
# consensys 437952 3.7714144623603363 0.012269587160679687
# rocket-pool 420293.6843150613 2.3258919402939675 0.011774874855661895
# coinbase 393750.6013650619 2.84565 0.011031248454211122
# kelp-dao 367008.16880715766 2.56 0.010282037108771886
# liquid-collective 340470.2198396935 3.2511031774970736 0.00953855454008406
# stake-fish 321046.1103665485 2.89 0.008994372063010462
# kiln 318685 2.8011507630000003 0.008928223605101029
# lido-finance 272613.9 3.06 0.007637503669951996
# darma-capital 272374.5014102971 2.79 0.007630796720645899
# lido-finance 247841.4280675735 2.9 0.00694348239921822
# lido-finance 247841.4280675735 2.83 0.00694348239921822
# lido-finance 247841.4280675735 2.76 0.00694348239921822
# lido-finance 247841.4280675735 2.82 0.00694348239921822
# launchnodes 247841.4280675735 2.8 0.00694348239921822
# infstones 247841.4280675735 2.89 0.00694348239921822
# lido-finance 247841.4280675735 2.86 0.00694348239921822
# simply-staking 247805.56100128294 2.88 0.006942477553719057
# stakely 247805.56100128294 2.8 0.006942477553719057
# chorus-one 247805.56100128294 2.76 0.006942477553719057
# attestant 247805.56100128294 2.81 0.006942477553719057
# hashquark 247805.56100128294 2.79 0.006942477553719057
# staking-facilities 247805.56100128294 2.87 0.006942477553719057
# stake-fish 247805.56100128294 2.92 0.006942477553719057
# blockscape 247805.56100128294 2.86 0.006942477553719057
# allnodes 247805.56100128294 2.85 0.006942477553719057
# lido-finance 247805.56100128294 2.87 0.006942477553719057
# lido-finance 247805.56100128294 2.82 0.006942477553719057
# lido-finance 247805.56100128294 2.88 0.006942477553719057
# lido-finance 247805.56100128294 2.94 0.006942477553719057
# chainlayer 247805.56100128294 2.82 0.006942477553719057
# lido-finance 247805.56100128294 2.86 0.006942477553719057
# blockdaemon 247805.56100128294 2.82 0.006942477553719057
# stakin 247805.56100128294 2.78 0.006942477553719057
# figment-networks 247805.56100128294 2.77 0.006942477553719057
# rockx 247805.56100128294 2.87 0.006942477553719057
# dsrv 247805.56100128294 2.91 0.006942477553719057
# p2p-validator 238080 2.66109322485 0.006670007926016139
# lido-finance 238005.54032719167 2.9 0.006667921876756226
# allnodes 218538.03490820914 2.83 0.006122523626401826
# infstones 205600 3.0969282901569564 0.00576005388772227
# renzo 197792.60446126014 2.664205453278279 0.005541323250436745
# stakewise 197424.88842874963 0 0.005531021381941415
# kiln 171946.71579680857 2.87 0.004817229322988733
# allnodes 170691.36847663997 2.87 0.0047820597305180184
# nodemonster 161078.9947107775 2.81 0.004512761136742262
# eigenyields 155163.23715895752 None 0.004347026300724834
# stake-fish 155089.1946402587 2.79 0.004344951938381994
# staking-facilities 150853.31931419202 2.837352003015948 0.004226280391009343
# stader-labs 149451.5623932781 2.62 0.0041870090125951795
# pier-two 146229.88581447874 2.92 0.004096751081161828
# hashquark 144185.6064879371 2.87 0.00403947890663636
# coinbase-cloud 121661.08885748325 2.94 0.003408435933161824
# chainnodes 115850.62411841712 2.8 0.0032456509622973734
# consensys 114523.54266566745 2.91 0.003208471678828332
# golem-foundation 112479.11988710715 2.83 0.0031511954853760257
# validation-cloud 112192.1833567829 2.75 0.0031431567213827194
# a41 107852.26833562857 2.8 0.0030215704159839633
# infstones 107601.19887159485 2.83 0.0030145364974898206
# frax-finance 98616.43073534127 3.9498011951408807 0.0027628207940194383
# a41 93828.24541603071 2.82 0.0026286758258111235
# ether-fi 93254.3723553822 2.79 0.002612598297824511
# dsrv 88519.91960503203 2.77 0.002479958691934959
# ebunker 84359.33991533036 2.83 0.002363396614032019
# nethermind 82565.98660080378 2.9 0.0023131543390738554
# cosmostation 78513.00810997371 2.92 0.002199606797668406
# lido-finance 77485.40915742492 2.99 0.0021708177639055263
# coinbase-cloud 75284.97214382587 2.81 0.0021091707027437114
# blockdaemon 75284.97214382587 3.08 0.0021091707027437114
# figment-networks 75284.97214382587 2.94 0.0021091707027437114
# blockdaemon 69689.70980250293 2.86 0.0019524148048742404
# luganodes 67896.35648797636 2.89 0.0019021725299160769
# chorus-one 62121.75881520076 2.91 0.0017403924045507897
# pier-two 60113.203102930995 2.79 0.0016841210565976465
# ether-fi 60041.46897034993 2.78 0.00168211136559932
# bitstamp 59916.66100396967 3.05 0.0016786147672920857
# luganodes 57710.10966146537 2.82 0.001616796408153707
# staked-us 52788.84 3.24 0.001478922972132047
# staked-us 52756.729999999996 3.19 0.001478023383949485
# staked-us 52756.729999999996 3.14 0.001478023383949485
# staked-us 52756.729999999996 4.46 0.001478023383949485
# staked-us 52756.729999999996 2.99 0.001478023383949485
# staked-us 52756.729999999996 3.16 0.001478023383949485
# staked-us 52756.729999999996 3.13 0.001478023383949485
# frax-finance 52206.62217746699 3.9498011951408807 0.0014626116587459458
# luganodes 48205.3370944745 2.85 0.0013505123508754397
# rocket-pool 46196.781382204725 2.98 0.0012942410029222963
# renzo-operated-by-luganodes 45845.55965275192 None 0.0012844012359564056
# etherfi-12 45256.952608627544 None 0.0012679109232479942
# kiln 41097.68563374714 None 0.0011513856221354714
# infstones 36839.828152569615 None 0.0010320982265234872
# coinsummer-labs 36384.70423288916 None 0.0010193475538437654
# altlayer 32557.137171186805 None 0.0009121150998832772
# darma-capital 32101.024330025797 2.89 0.0008993367217511298
# chainup-cloud 30845.67700985719 2.87 0.0008641671292804153
# swell-infstones 28512 None 0.0007987872395269327
# hashquark 20718.916949872524 None 0.0005804575784363233
# alphanodes 20623.56311705568 2.95 0.0005777861620188823
# swell-network 20342.365275609223 3.2113302895422207 0.0005699081721363785
# stakin 18901.94393511016 2.78 0.0005295535780590451
# hord 18324.566152547824 2.44 0.0005133778623920575
# swell-network 18034.75541538657 2.4948639369858134 0.0005052585751192495
# stakely 17467.261283488897 2.74 0.0004893597580925142
# puffer-coinsummer 16226.172725598462 None 0.00045458963662906856
# puffer 16055 2.92 0.0004497940912810362
# rockx 9899.310296186726 2.68 0.0002773373577690635
# xhash 9540.639633281411 3.11 0.0002672889027774308
# ankr 9282.506496025546 2.43444 0.0002600570896412411
# ebunker 9110.234837795031 2.79 0.00025523075678747146
# swell-a41 8512 None 0.00023847071348391034
# mev-protocol 8440.908 3.708 0.00023647901236043778
# dinero 8164.604549021879 3.91 0.00022873814287114987
# alphanodes 7532.08392101164 2.81 0.00021101755482428745
# luganodes 7173.413258106323 2.63 0.00020096909983265468
# serenita 6886.47672778207 2.56 0.0001929303358393485
# luganodes 6875.8245230333605 None 0.0001926319055213737
# allnodes 6067.939998291025 None 0.00016999835300399654
# cryptonative-systems 6061.534203099844 2.74 0.00016981888935859322
# dinero 5889.8036941505325 3.91 0.00016500771724908933
# a41 5359.812413509248 None 0.00015015957358898845
# hyperledger-besu 5164.857545836553 2.26 0.0001446977518795114
# prysm-ethereum-client 5164.857545836553 2.7 0.0001446977518795114
# teku 5164.857545836553 2.51 0.0001446977518795114
# nimbus 5093.12341325549 2.96 0.00014268806088118486
# erigon 4590.984485188047 3 0.000128620223892899
# yieldnest 4203.2389807088575 2.386453652623974 0.00011775721318997008
# rockx 3730.174894215288 2.72 0.00010450393191298044
# blockscape 3694.3078279247566 3.12 0.00010349908641381718
# swell-network 3694.3078279247566 2.41 0.00010349908641381718
# infstones 3694.3078279247566 2.47 0.00010349908641381718
# dsrv 3694.3078279247566 2.56 0.00010349908641381718
# stakely 3694.3078279247566 2.94 0.00010349908641381718
# lido-finance 3463.6861646251355 4.18 9.70380299533018e-05
# polkachucom 3457.463778536907 None 9.686370466546907e-05
# lido-finance 3200 2.7731392553700003 8.965064416688358e-05
# infstones 2853.24768138146 2.34 7.993609143859841e-05
# globalstake 2295.4922425940235 2.58 6.43101119464495e-05
# rocket-pool 2152.023977431897 2.31 6.029072994979641e-05
# allnodes 2116.1569111413655 2.97 5.928588445063314e-05
# stafi-protocol 2042.3259851105847 2.151729819834537 5.7217450051227816e-05
# lighthouse 1865.087447107644 3.03 5.225196595649022e-05
# pier-two 1583.2335055756612 None 4.435559488795353e-05
# validation-cloud 1327.0814527496698 2.77 3.717928346904112e-05
# coinbase 1303.4227985998452 6.69 3.651646672383697e-05
# blockshard 1153.0962421232593 None 3.2304944028988425e-05
# myrmidonstaking 932.543723553822 2.57 2.612598297824511e-05
# colossus 932.543723553822 3.67 2.612598297824511e-05
# cian 904.1453613641138 2.16 2.533037939587267e-05
# 01node 833.8391176723159 None 2.336069188464655e-05
# digital-asset-management-network 714.1586597360084 None 2.0007744963341056e-05
# metapool 711.0897787334926 3 1.9921767726232604e-05
# a41 691.7421552787588 2.31 1.9379728068165356e-05
# bifrost-finance 688.6133575790643 2.9322 1.9292072215276145e-05
# ebunker 674.31 2.37 1.8891351833803522e-05
# senseinode 560.3856932913275 4.24 1.5699668245460364e-05
# unity-capital 447.186469493075 None 1.252829845399019e-05
# kiln 394.5377291958478 2.31 1.1053300490796009e-05
# cosmostation 371.2569248706433 None 1.040106952064671e-05
# chainlabo 358.6706629053162 2.8 1.0048454991632736e-05
# ledger-live 352 0 9.861570858357195e-06
# blockpower-2 320 None 8.965064416688358e-06
# pro-delegators 313.41082935531495 None 8.780463356431629e-06
# brick-towers 286.93653032425294 2.31 8.038763993306188e-06
# bware-labs 273.330454754063 None 7.657578543477805e-06
# senseinode 251.06946403372132 3.48 7.033918494142915e-06
# stakecat 226.28414860038077 None 6.33953740211842e-06
# astro-stakers 215.2023977431897 2.31 6.029072994979641e-06
# kukisglobal 197.15024940312517 None 5.523327142703727e-06
# validao 173.7766147230892 None 4.868495453457905e-06
# bella-protocol 167.13374284407024 None 4.6823899087478645e-06
# segment 149.81904209846502 0.053032773440092225 4.1973042601852624e-06
# memecoins-outmatch-da 147.33060867600784 None 4.127588741657235e-06
# da3m0ns 143.07386301347276 None 4.0083324945632165e-06
# swiss-staking 126.70245922235713 None 3.5496740896289427e-06
# kiln 106.886410021364 5.3 2.9945110972190387e-06
# kiln 103.06842636743343 2.31 2.8875471303460676e-06
# dsrv-all-avss 102.4278325122254 None 2.869600364168334e-06
# kingsuper 93.94963507427498 None 2.6320766573913725e-06
# abacus-works-avs-operator 86.98251752768932 None 2.4368871023795596e-06
# kiln 71.75182636111367 2.31 2.0101867041950686e-06
# blockdaemon 71.73413258106324 2.31 2.009690998326547e-06
# mulbot 65.68346806890044 None 1.8401766323412043e-06
# tbd-dao 64 None 1.7930128833376717e-06
# informal-systems 64 None 1.7930128833376717e-06
# daveydoo 62.70243549081741 None 1.7566605414325763e-06
# nodesup 50.24537410577621 None 1.407665673434028e-06
# orangefin-ventures 49.90622556361627 None 1.3981641467862473e-06

# %%
plot_lorenz_curve(resp_solana, title="Solana provider staked tokens")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plot_lorenz_curve(resp_solana, title="Solana provider staked tokens")
#
# NameError: name 'plot_lorenz_curve' is not defined

# %%
def create_distribution(asset_slug):
    resp = client.get_provider_stake_shares(asset_slug=asset_slug, limit=200, is_active=True, include_reward_rate=True)
    plot_lorenz_curve(resp, title=f"Provider staked token for {asset_slug}")
    print(f'Untracked share for {asset_slug}: {resp["untracked_share"]}')

# %%
def create_distributions(asset_slugs):
    for asset_slug in asset_slugs:
        create_distribution(asset_slug)

# %%
# Solana
create_distribution("solana")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Solana
# ----> 2 create_distribution("solana")
#
# Cell In[14], line 3, in create_distribution(asset_slug)
#       1 def create_distribution(asset_slug):
#       2     resp = client.get_provider_stake_shares(asset_slug=asset_slug, limit=200, is_active=True, include_reward_rate=True)
# ----> 3     plot_lorenz_curve(resp, title=f"Provider staked token for {asset_slug}")
#       4     print(f'Untracked share for {asset_slug}: {resp["untracked_share"]}')
#
# Cell In[10], line 18, in plot_lorenz_curve(stake_shares_response, ax, title)
#      16 staked_sorted = sorted(staked)
#      17 n = len(staked_sorted)
# ---> 18 total = sum(staked_sorted)
#      19 cumulative = []
#      20 running = 0.0
#
# TypeError: 'float' object is not callable

# %%
# TRON
create_distribution("ethereum-2-0")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 # TRON
# ----> 2 create_distribution("ethereum-2-0")
#
# Cell In[14], line 3, in create_distribution(asset_slug)
#       1 def create_distribution(asset_slug):
#       2     resp = client.get_provider_stake_shares(asset_slug=asset_slug, limit=200, is_active=True, include_reward_rate=True)
# ----> 3     plot_lorenz_curve(resp, title=f"Provider staked token for {asset_slug}")
#       4     print(f'Untracked share for {asset_slug}: {resp["untracked_share"]}')
#
# Cell In[10], line 18, in plot_lorenz_curve(stake_shares_response, ax, title)
#      16 staked_sorted = sorted(staked)
#      17 n = len(staked_sorted)
# ---> 18 total = sum(staked_sorted)
#      19 cumulative = []
#      20 running = 0.0
#
# TypeError: 'float' object is not callable

# %%
create_distribution("babylon")
# Out:
# Untracked share for babylon: 0.06484386502765468

# %%
assets = [
    "ethereum-2-0",
    "binance-smart-chain",
    "solana",
    "cardano", 
    "waves", 
    "cosmos", 
    "avalanche", 
    "hyperliquid",
    "tron",
    "sui",
    "bittensor",
    "hedera-hashgraph",
    "aptos",
    "crypto-com-coin",
    "near-protocol",
    "story-network",
    "sei-network",
    "stacks",
    "tezos",
    "monad",
    "injective-protocol",
    "algorand",
    "celestia",
    "iota",
    "aleo",
    "fetch-ai",
    "starknet"
]

assets_on_rated = [
    "solana",
    "cardano",
    "celestia",
    "ethereum-2-0",
    "matic-network", # Polygon
    "avalanche",
    "polkadot,
    "cosmos",
    "eigenlayer",
    "babylon"
]

# %%
create_distributions(assets)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 create_distributions(assets)
#
# NameError: name 'create_distributions' is not defined

# %%
import math
from typing import Optional
import matplotlib.pyplot as plt
import numpy as np

def _extract_points(stake_shares_response):
    """
    Extract (stake, reward_rate) pairs from get_provider_stake_shares response.

    Returns a list of (stake, reward_rate) tuples with both values present and > 0.
    """
    providers = stake_shares_response.get("providers") or []
    points = []
    for p in providers:
        stake = p.get("staked_tokens")
        rr = p.get("reward_rate")
        if stake is None or rr is None:
            continue
        try:
            stake_val = float(stake)
            rr_val = float(rr)
        except (TypeError, ValueError):
            continue
        if stake_val <= 0 or rr_val <= 0:
            continue
        points.append((stake_val, rr_val))
    return points

def plot_reward_rate_vs_stake(stake_shares_response, ax: Optional[plt.Axes] = None, title: Optional[str] = None, logx: bool = True, logy: bool = True):
    """
    Scatter + simple regression line for reward_rate vs staked_tokens.

    Args:
        stake_shares_response (dict): Response from get_provider_stake_shares
        ax (matplotlib.axes.Axes, optional): Axis to draw on; creates a new one if None.
        title (str, optional): Plot title.
        logx (bool, optional): Log scale for x (stake). Default True.
        logy (bool, optional): Log scale for y (reward rate). Default True.

    Returns:
        matplotlib.axes.Axes: The axis with the plot.

    Raises:
        ValueError: If fewer than two data points are available.
    """
    points = _extract_points(stake_shares_response)
    if len(points) < 2:
        raise ValueError("Need at least two providers with staked_tokens and reward_rate to plot regression.")

    stakes, reward_rates = zip(*points)
    stakes = np.array(stakes)
    reward_rates = np.array(reward_rates)

    ax = ax or plt.subplots(figsize=(7, 5))[1]
    ax.scatter(stakes, reward_rates, alpha=0.6, label="providers")

    # Regression on log-transformed data for robustness across magnitudes
    log_stakes = np.log(stakes)
    log_rr = np.log(reward_rates)
    slope, intercept = np.polyfit(log_stakes, log_rr, 1)
    fitted = np.exp(intercept) * stakes ** slope
    ax.plot(stakes, fitted, color="orange", label=f"fit: y = {math.exp(intercept):.3g} * x^{slope:.2f}")

    if logx:
        ax.set_xscale("log")
    if logy:
        ax.set_yscale("log")

    ax.set_xlabel("Staked tokens")
    ax.set_ylabel("Reward rate")
    if title:
        ax.set_title(title)
    ax.legend()
    ax.grid(True, which="both", ls="--", alpha=0.3)
    return ax

# %%
asset_slug=assets[6]
resp = client.get_provider_stake_shares(asset_slug=asset_slug, limit=200, is_active=True, include_reward_rate=True)
print([prov["reward_rate"] for prov in resp["providers"]])
plot_reward_rate_vs_stake(resp, title=f"Provider staked token for {asset_slug}")
# Out:
# [4.953185270935226, 6.761219116716955, 5.128081087990655, 5.256890011279049, 5.550113603217018, 5.431166354749563, 4.24300561625051, 4.411465803506631, 5.003914779061452, 5.2012582753192005, 5.423108847985717, 5.09914598922659, 5.105361022081788, 6.338983941539193, 1.8889619184576987, 5.099970164425405, 5.593614233376213, 5.101823024693363, 5.100430465057795, 5.102958560636557, 4.535838127273348, 5.102154190077619, 5.624783903478171, 5.260890946450333, 5.1036233663927355, 5.4250281960920725, 5.540664518998523]
# <Axes: title={'center': 'Provider staked token for avalanche'}, xlabel='Staked tokens', ylabel='Reward rate'>

# %%
import pandas as pd


def gini_from_stake_response(resp):
    """
    Compute Gini coefficient from get_provider_stake_shares response.
    Returns None if no staked token data is present.
    """
    providers = resp.get("providers") or []
    staked = [p.get("staked_tokens") for p in providers if p.get("staked_tokens") not in (None, 0)]
    if not staked:
        return None
    staked_sorted = sorted(staked)
    total = sum(staked_sorted)
    n = len(staked_sorted)
    if total == 0:
        return None
    area = 0.0
    running = 0.0
    for value in staked_sorted:
        prev = running / total
        running += value
        curr = running / total
        width = 1 / n
        area += width * (curr + prev) / 2
    return 1 - 2 * area


def weighted_average_reward_rate(providers):
    weighted_sum = 0.0
    total_weight = 0.0
    for p in providers:
        rr = p.get("reward_rate")
        stake = p.get("staked_tokens")
        if rr is None or stake in (None, 0):
            continue
        try:
            rr_val = float(rr)
            stake_val = float(stake)
        except (TypeError, ValueError):
            continue
        weighted_sum += rr_val * stake_val
        total_weight += stake_val
    if total_weight == 0:
        return None
    return weighted_sum / total_weight


rows = []
for asset_slug in assets:
    resp = client.get_provider_stake_shares(asset_slug=asset_slug, limit=200, is_active=True, include_reward_rate=True)
    providers = resp.get("providers") or []
    rows.append({
        "asset": asset_slug,
        "gini_coefficient": gini_from_stake_response(resp),
        "total_staked_tokens": resp.get("total_staked_tokens"),
        "uncovered_staking_part": resp.get("untracked_share"),
        "average_reward_rate": weighted_average_reward_rate(providers),
    })

summary_df = pd.DataFrame(rows)
summary_df
# Out:
#                   asset  gini_coefficient  total_staked_tokens  \
# 0          ethereum-2-0          0.891494         3.569411e+07
# 1   binance-smart-chain          0.412434         2.542967e+07
# 2                solana          0.575564         4.138471e+08
# 3               cardano          0.362558         2.101982e+10
# 4                 waves          0.761370         2.166231e+07
# 5                cosmos          0.791212         2.854351e+08
# 6             avalanche          0.676533         2.085705e+08
# 7           hyperliquid          0.827883         4.311673e+08
# 8                  tron          0.287679         4.331291e+10
# 9                   sui          0.375899         7.478759e+09
# 10            bittensor          0.610644         7.369206e+06
# 11     hedera-hashgraph          0.015370         1.596011e+10
# 12                aptos          0.472780         8.321842e+08
# 13      crypto-com-coin          0.880604         1.213829e+10
# 14        near-protocol          0.728600         5.879019e+08
# 15        story-network          0.567973         5.037688e+08
# 16          sei-network          0.391544         4.355062e+09
# 17               stacks          0.682533                  NaN
# 18                tezos          0.859691         6.386396e+08
# 19                monad          0.240429         1.424952e+10
# 20   injective-protocol          0.527084         5.715851e+07
# 21             algorand          0.892081                  NaN
# 22             celestia          0.460189         4.405548e+08
# 23                 iota          0.531096         2.407805e+09
# 24                 aleo          0.558070         1.337066e+09
# 25             fetch-ai          0.777210         6.069493e+08
# 26             starknet          0.786672         1.114298e+09
#
#     uncovered_staking_part  average_reward_rate
# 0                      NaN             3.876372
# 1             0.000000e+00             0.498212
# 2             5.730493e-01             6.352880
# 3             3.556190e-01             2.376221
# 4             2.494765e-01             5.655753
# 5                      NaN            16.924993
# 6             6.575791e-01             5.470428
# 7                      NaN             2.153416
# 8             4.686949e-02             3.142734
# 9                      NaN             1.833501
# 10            5.316868e-01             4.933766
# 11            1.132279e-01             2.564110
# 12            7.070494e-01             3.230323
# 13            5.538788e-02             1.765584
# 14            9.413110e-04             4.370565
# 15            1.023549e-01             3.318713
# 16            3.121603e-02             5.287484
# 17                     NaN             8.823757
# 18            2.294081e-01             8.152661
# 19            7.801685e-02            12.763193
# 20            1.426255e-02             9.710978
# 21                     NaN             4.692029
# 22            4.221585e-03             4.745747
# 23            3.960762e-16            11.626978
# 24            5.516473e-01             9.907175
# 25                     NaN             4.928934
# 26            3.554345e-01             8.688336

# %%
import json
import pandas as pd

# Set the asset slug to inspect
asset_slug = "avalanche"

# Provider stake + reward data
resp = client.get_provider_stake_shares(
    asset_slug=asset_slug,
    limit=200,
    is_active=True,
    include_reward_rate=True
)
providers = resp.get("providers") or []

# Fetch staking type information per provider
query = f"""
{{
  rewardOptions(
    where: {{ inputAsset: {{ slugs: [{json.dumps(asset_slug)}] }} }}
    limit: 200
    order: {{ metricKey_desc: "staked_tokens" }}
  ) {{
    providers(limit: 1) {{ slug name }}
    type {{ key label }}
  }}
}}
"""
type_result = client.execute_raw_query(query)
provider_types = {}
for ro in type_result.get("data", {}).get("rewardOptions", []) or []:
    prov = (ro.get("providers") or [{}])[0]
    slug = prov.get("slug")
    stake_type = None
    ro_type = ro.get("type")
    if ro_type:
        stake_type = ro_type.get("label") or ro_type.get("key")
    if slug and slug not in provider_types:
        provider_types[slug] = stake_type

# Build table
rows = []
for p in providers:
    slug = p.get("provider")
    rows.append({
        "provider": p.get("name") or slug,
        "staked_tokens": p.get("staked_tokens"),
        "percentage_of_total": (p.get("share") * 100) if p.get("share") is not None else None,
        "staking_type": provider_types.get(slug),
        "reward_rate": p.get("reward_rate"),
    })

df = pd.DataFrame(rows)
df = df.sort_values(by="percentage_of_total", ascending=False).reset_index(drop=True)
df
# Out:
#                 provider  staked_tokens  percentage_of_total    staking_type  \
# 0   BENQI Liquid Staking   2.495062e+07            11.962683  liquid-staking
# 1               Allnodes   1.892855e+07             9.075374         hosting
# 2               GoGoPool   2.925044e+06             1.402425  liquid-staking
# 3                    091   2.700000e+06             1.294527             pos
# 4                    060   2.136406e+06             1.024309             pos
# 5                    059   2.078923e+06             0.996749             pos
# 6                   Kiln   1.937723e+06             0.929050             pos
# 7                    081   1.837000e+06             0.880758             pos
# 8                    085   1.512055e+06             0.724961             pos
# 9                    086   1.498000e+06             0.718223             pos
# 10                   096   1.350000e+06             0.647263             pos
# 11                   028   1.009744e+06             0.484126             pos
# 12                   049   9.301991e+05             0.445988             pos
# 13      Tranquil Grizzly   9.176620e+05             0.439977             pos
# 14            Chorus One   8.541288e+05             0.409516             pos
# 15                   027   6.930000e+05             0.332262             pos
# 16            SenseiNode   6.902096e+05             0.330924             pos
# 17                   014   6.270000e+05             0.300618             pos
# 18                   051   5.940000e+05             0.284796             pos
# 19                   031   4.950000e+05             0.237330             pos
# 20                   082   4.800000e+05             0.230138             pos
# 21                   050   4.620000e+05             0.221508             pos
# 22       Omnivorous Pika   4.327260e+05             0.207472             pos
# 23                   055   4.062218e+05             0.194765             pos
# 24                   016   3.568009e+05             0.171070             pos
# 25    Ultimate Validator   3.123483e+05             0.149757             pos
# 26      Digital Cleavage   3.035240e+05             0.145526             pos
#
#     reward_rate
# 0      4.953185
# 1      6.761219
# 2      5.128081
# 3      5.256890
# 4      5.550114
# 5      5.431166
# 6      4.243006
# 7      4.411466
# 8      5.003915
# 9      5.201258
# 10     5.423109
# 11     5.099146
# 12     5.105361
# 13     6.338984
# 14     1.888962
# 15     5.099970
# 16     5.593614
# 17     5.101823
# 18     5.100430
# 19     5.102959
# 20     4.535838
# 21     5.102154
# 22     5.624784
# 23     5.260891
# 24     5.103623
# 25     5.425028
# 26     5.540665
